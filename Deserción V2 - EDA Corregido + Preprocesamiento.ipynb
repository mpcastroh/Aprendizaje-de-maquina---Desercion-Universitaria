# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
# Configuración de visualización
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 10

# %% [markdown]
# # EDA

# %% [markdown]
# # 1. CARGA DE LA INFORMACIÓN

# %%
notas = pd.read_csv("notas.txt", engine="python", sep=None)

# %%
notas.shape
# Out:
# (2194612, 36)

# %%
notas[notas['EMPLID_ANÓNIMO']==1000].head(5)
# Out:
#            EMPLID NIVEL ACADÉMICO  CICLO  ID_MATERIA NRO_MATERIA  \
# 29572  1000099498            PREG    210      118876      IP0195
# 29573  1000099498            PREG    210      118785      IP0104
# 30344  1000099498            PREG    225      118791      IP0110
# 30345  1000099498            PREG    205      126455      ST0319
# 31067  1000099498            PREG    210      118790      IP0109
#
#                   NOMBRE_MATERIA  COD_PROGRAMA NIVEL_ACADÉMICO_CURSO  \
# 29572   PRODUCCIÓN SISTEMÁTICA 1            12                  PREG
# 29573                    ENSAYOS            12                  PREG
# 30344  PROCESOS DE MANUFACTURA 2            12                  PREG
# 30345              ESTADÍSTICA 2            12                  PREG
# 31067  PROCESOS DE MANUFACTURA 1            12                  PREG
#
#       ESTADO_INSCRIP_ESTUD DESC_ESTADO_INSCRIP_ESTUD  ... FIRST_GENERATION  \
# 29572                    E                  Inscrito  ...              NaN
# 29573                    E                  Inscrito  ...              NaN
# 30344                    E                  Inscrito  ...              NaN
# 30345                    E                  Inscrito  ...              NaN
# 31067                    E                  Inscrito  ...              NaN
#
#       DESPLAZADO_VICTIMA_CONFLICTO           NOMBRE_PROGRAMA COHORTE  \
# 29572                          NaN  Ingeniería de Producción  2002-2
# 29573                          NaN  Ingeniería de Producción  2002-2
# 30344                          NaN  Ingeniería de Producción  2002-2
# 30345                          NaN  Ingeniería de Producción  2002-2
# 31067                          NaN  Ingeniería de Producción  2002-2
#
#          CONCATENADO DESERTOR GRADUADO  ACTIVO                        Escuela  \
# 29572  1000099498012      0.0      1.0     0.0  E Ciencias Aplic e Ingeniería
# 29573  1000099498012      0.0      1.0     0.0  E Ciencias Aplic e Ingeniería
# 30344  1000099498012      0.0      1.0     0.0  E Ciencias Aplic e Ingeniería
# 30345  1000099498012      0.0      1.0     0.0  E Ciencias Aplic e Ingeniería
# 31067  1000099498012      0.0      1.0     0.0  E Ciencias Aplic e Ingeniería
#
#       Estrato
# 29572     NaN
# 29573     NaN
# 30344     NaN
# 30345     NaN
# 31067     NaN
#
# [5 rows x 36 columns]

# %%
notas.head()
# Out:
#        EMPLID NIVEL ACADÉMICO  CICLO  ID_MATERIA NRO_MATERIA  \
# 0  1000166060            PREG   2561      121031      MU0499
# 1  1000109890            PREG   2266      129738      PT0231
# 2  1000136707            PREG   2561      129703      PT0207
# 3  1000237090            PREG   2466      129703      PT0207
# 4  1000207743            PREG   2261      112801      EC0200
#
#               NOMBRE_MATERIA  COD_PROGRAMA NIVEL_ACADÉMICO_CURSO  \
# 0  RECITAL PROYECTO DE GRADO            83                  PREG
# 1           EMPRESARISMO 001             1                  PREG
# 2             VALIDACIÓN 001             1                  PREG
# 3             VALIDACIÓN 001             1                  PREG
# 4           TRABAJO DE GRADO             3                  PREG
#
#   ESTADO_INSCRIP_ESTUD DESC_ESTADO_INSCRIP_ESTUD  ... FIRST_GENERATION  \
# 0                    E                  Inscrito  ...              1.0
# 1                    E                  Inscrito  ...              NaN
# 2                    E                  Inscrito  ...              1.0
# 3                    E                  Inscrito  ...              0.0
# 4                    E                  Inscrito  ...              0.0
#
#   DESPLAZADO_VICTIMA_CONFLICTO             NOMBRE_PROGRAMA COHORTE  \
# 0                          NaN                      Música  2021-1
# 1                          NaN  Administración de Negocios  2020-1
# 2                          NaN  Administración de Negocios  2019-2
# 3                          NaN  Administración de Negocios  2020-1
# 4                          NaN                    Economía  2016-1
#
#      CONCATENADO DESERTOR GRADUADO  ACTIVO                         Escuela  \
# 0  1000166060083      0.0      0.0     1.0  Escuela de Artes y Humanidades
# 1  1000109890001      0.0      1.0     0.0       Escuela de Administración
# 2  1000136707001      0.0      0.0     1.0       Escuela de Administración
# 3  1000237090001      0.0      0.0     1.0       Escuela de Administración
# 4  1000207743003      0.0      1.0     0.0  E.Finanzas, Economía, Gobierno
#
#   Estrato
# 0     4.0
# 1     3.0
# 2     6.0
# 3     5.0
# 4     4.0
#
# [5 rows x 36 columns]

# %%
notas.dtypes
# Out:
# EMPLID                              int64
# NIVEL ACADÉMICO                    object
# CICLO                               int64
# ID_MATERIA                          int64
# NRO_MATERIA                        object
# NOMBRE_MATERIA                     object
# COD_PROGRAMA                        int64
# NIVEL_ACADÉMICO_CURSO              object
# ESTADO_INSCRIP_ESTUD               object
# DESC_ESTADO_INSCRIP_ESTUD          object
# MOTIVO_ESTADO_INSCRIP              object
# DESC_MOTIVO_ESTADO_INSCRIP         object
# ULT_ACCION_INSCRIPCION             object
# ULT_MOTIVO_ACCION_INSCRIPCION      object
# DESC_MOTIVO_ACCION_INSCRIPCION     object
# SISTEMA_CALIFICACION               object
# SEMESTRE                           object
# TIPO_SEMESTRE                     float64
# Semestre valor                      int64
# NOTA                               object
# CRÉDITOS                            int64
# UMES                                int64
# EMPLID_ANÓNIMO                      int64
# DISCAPACIDAD                       object
# First_generation ayre             float64
# First generation epik             float64
# FIRST_GENERATION                  float64
# DESPLAZADO_VICTIMA_CONFLICTO      float64
# NOMBRE_PROGRAMA                    object
# COHORTE                            object
# CONCATENADO                         int64
# DESERTOR                          float64
# GRADUADO                          float64
# ACTIVO                            float64
# Escuela                            object
# Estrato                           float64
# dtype: object

# %%
notas.columns
# Out:
# Index(['EMPLID', 'NIVEL ACADÉMICO', 'CICLO', 'ID_MATERIA', 'NRO_MATERIA',
#        'NOMBRE_MATERIA', 'COD_PROGRAMA', 'NIVEL_ACADÉMICO_CURSO',
#        'ESTADO_INSCRIP_ESTUD', 'DESC_ESTADO_INSCRIP_ESTUD',
#        'MOTIVO_ESTADO_INSCRIP', 'DESC_MOTIVO_ESTADO_INSCRIP',
#        'ULT_ACCION_INSCRIPCION', 'ULT_MOTIVO_ACCION_INSCRIPCION',
#        'DESC_MOTIVO_ACCION_INSCRIPCION', 'SISTEMA_CALIFICACION', 'SEMESTRE',
#        'TIPO_SEMESTRE', 'Semestre valor', 'NOTA', 'CRÉDITOS', 'UMES',
#        'EMPLID_ANÓNIMO', 'DISCAPACIDAD', 'First_generation ayre',
#        'First generation epik', 'FIRST_GENERATION',
#        'DESPLAZADO_VICTIMA_CONFLICTO', 'NOMBRE_PROGRAMA', 'COHORTE',
#        'CONCATENADO', 'DESERTOR', 'GRADUADO', 'ACTIVO', 'Escuela', 'Estrato'],
#       dtype='object')

# %%
notas.DESPLAZADO_VICTIMA_CONFLICTO.unique()
# Out:
# array([nan,  0.,  1.])

# %% [markdown]
# # 2. ANÁLISIS DE VALORES FALTANTES

# %%
def analizar_valores_faltantes(df):
    """
    Analiza y visualiza valores faltantes
    """
    print("\n" + "="*80)
    print("ANÁLISIS DE VALORES FALTANTES")
    print("="*80)
    
    # Calcular porcentajes de valores faltantes
    missing = pd.DataFrame({
        'Columna': df.columns,
        'Valores_Faltantes': df.isnull().sum(),
        'Porcentaje': (df.isnull().sum() / len(df) * 100).round(2)
    })
    missing = missing[missing['Valores_Faltantes'] > 0].sort_values('Porcentaje', ascending=False)
    
    if len(missing) > 0:
        print("\nColumnas con valores faltantes:")
        print(missing.to_string(index=False))
        
        # Visualización mejorada con etiquetas
        fig, ax = plt.subplots(figsize=(12, max(8, len(missing) * 0.4)))
        missing_sorted = missing.sort_values('Porcentaje')
        
        bars = ax.barh(missing_sorted['Columna'], missing_sorted['Porcentaje'], 
                       color='steelblue', edgecolor='black', alpha=0.7)
        ax.set_xlabel('Porcentaje de Valores Faltantes (%)', fontsize=12, fontweight='bold')
        ax.set_title('Valores Faltantes por Columna', fontsize=14, fontweight='bold', pad=15)
        ax.grid(True, alpha=0.3, axis='x')
        ax.tick_params(axis='both', labelsize=10)
        
        # Agregar etiquetas de datos
        for i, (bar, porcentaje, valores) in enumerate(zip(bars, missing_sorted['Porcentaje'], 
                                                             missing_sorted['Valores_Faltantes'])):
            width = bar.get_width()
            label = f'{porcentaje:.2f}% ({valores:,})'
            
            # Posicionar etiqueta dentro o fuera de la barra según el espacio
            if width > 5:  # Si la barra es suficientemente grande
                ax.text(width - 1, bar.get_y() + bar.get_height()/2., label,
                       ha='right', va='center', fontweight='bold', fontsize=9, color='white')
            else:
                ax.text(width + 0.5, bar.get_y() + bar.get_height()/2., label,
                       ha='left', va='center', fontweight='bold', fontsize=9, color='black')
        
        plt.tight_layout()
        plt.show()
        
        # Estadísticas adicionales
        print(f"\n📊 Resumen:")
        print(f"   • Columnas con valores faltantes: {len(missing)}")
        print(f"   • Total de valores faltantes: {missing['Valores_Faltantes'].sum():,}")
        print(f"   • Porcentaje promedio de faltantes: {missing['Porcentaje'].mean():.2f}%")
    else:
        print("\n✅ ¡No hay valores faltantes en el dataset!")

# %%
analizar_valores_faltantes(notas)
# Out:
# ================================================================================
# ANÁLISIS DE VALORES FALTANTES
# ================================================================================
#
# Columnas con valores faltantes:
#                        Columna  Valores_Faltantes  Porcentaje
#                  TIPO_SEMESTRE            2194612      100.00
# DESC_MOTIVO_ACCION_INSCRIPCION            2177011       99.20
#  ULT_MOTIVO_ACCION_INSCRIPCION            2176626       99.18
#                   DISCAPACIDAD            2164256       98.62
#          First generation epik            1963072       89.45
#   DESPLAZADO_VICTIMA_CONFLICTO            1689990       77.01
#          First_generation ayre            1099770       50.11
#               FIRST_GENERATION             934503       42.58
#                        Estrato             630186       28.72
#         ULT_ACCION_INSCRIPCION              42477        1.94
#                       DESERTOR                327        0.01
#                       GRADUADO                327        0.01
#                         ACTIVO                327        0.01
# 📊 Resumen:
#    • Columnas con valores faltantes: 13
#    • Total de valores faltantes: 15,073,484
#    • Porcentaje promedio de faltantes: 52.83%

# %% [markdown]
# ### 2.1 Limpieza y preparación del dataset para el análisis

# %%
notas = notas [[ 'EMPLID_ANÓNIMO','NIVEL ACADÉMICO','SEMESTRE', 'ID_MATERIA', 'NRO_MATERIA',
       'NOMBRE_MATERIA', 'COD_PROGRAMA', 'NOMBRE_PROGRAMA','Escuela','NIVEL_ACADÉMICO_CURSO',
       'SISTEMA_CALIFICACION', 'NOTA', 'CRÉDITOS',
        'DISCAPACIDAD', 'FIRST_GENERATION',
       'DESPLAZADO_VICTIMA_CONFLICTO', 'COHORTE', 'DESERTOR', 'GRADUADO', 'ACTIVO','Estrato']]

# %%
notas.columns = ['EMPLID_ANÓNIMO','NIVEL_ACADEMICO','SEMESTRE', 'ID_MATERIA', 'NRO_MATERIA',
       'NOMBRE_MATERIA', 'COD_PROGRAMA', 'NOMBRE_PROGRAMA','ESCUELA','NIVEL_ACADÉMICO_CURSO',
       'SISTEMA_CALIFICACION', 'NOTA', 'CRÉDITOS',
        'DISCAPACIDAD', 'FIRST_GENERATION',
       'DESPLAZADO_VICTIMA_CONFLICTO', 'COHORTE', 'DESERTOR', 'GRADUADO', 'ACTIVO','ESTRATO']

# %%
print("\nTipos de datos:")
print(notas.dtypes.sort_values())
# Out:
# Tipos de datos:
# EMPLID_ANÓNIMO                    int64
# ID_MATERIA                        int64
# COD_PROGRAMA                      int64
# CRÉDITOS                          int64
# GRADUADO                        float64
# DESERTOR                        float64
# DESPLAZADO_VICTIMA_CONFLICTO    float64
# FIRST_GENERATION                float64
# ACTIVO                          float64
# ESTRATO                         float64
# ESCUELA                          object
# NOTA                             object
# NOMBRE_PROGRAMA                  object
# DISCAPACIDAD                     object
# NOMBRE_MATERIA                   object
# NRO_MATERIA                      object
# COHORTE                          object
# SEMESTRE                         object
# NIVEL_ACADEMICO                  object
# NIVEL_ACADÉMICO_CURSO            object
# SISTEMA_CALIFICACION             object
# dtype: object

# %%
notas["NOTA"] = notas["NOTA"].astype("string").str.replace(",", ".", regex=False)

# %%
notas["EMPLID_ANÓNIMO"] = notas["EMPLID_ANÓNIMO"].astype('string')
notas["ID_MATERIA"] = notas["ID_MATERIA"].astype('string')
notas["COD_PROGRAMA"] = notas["COD_PROGRAMA"].astype('string')
# notas["GRADUADO"] = notas["GRADUADO"].astype(bool)
# notas["DESERTOR"] = notas["DESERTOR"].astype(bool)
# notas["ACTIVO"] = notas["ACTIVO"].astype(bool)
# notas["DESPLAZADO_VICTIMA_CONFLICTO"] = notas["DESPLAZADO_VICTIMA_CONFLICTO"].astype(bool)
# notas["FIRST_GENERATION"] = notas["FIRST_GENERATION"].astype(bool)
notas["ESTRATO"] = notas["ESTRATO"].astype("Int64")
# notas["ESTRATO"] = notas["ESTRATO"].astype('string')
notas["NOTA"] = notas["NOTA"].astype(float)

# %%
print("Verificando NaN en variables binarias antes de convertir...")

# Verificar y llenar NaN en cada variable binaria
variables_binarias = ['GRADUADO', 'DESERTOR', 'ACTIVO', 
                      'DESPLAZADO_VICTIMA_CONFLICTO', 'FIRST_GENERATION']

for var in variables_binarias:
    nan_count = notas[var].isnull().sum()
    if nan_count > 0:
        print(f"  • {var}: {nan_count} NaN encontrados → Llenando con 0")
    notas[var].fillna(0, inplace=True)

print("✅ NaN llenados con 0 en todas las variables binarias")

# Ahora sí, convertir a bool (sin riesgo de que NaN se convierta a True)
notas["GRADUADO"] = notas["GRADUADO"].astype(bool)
notas["DESERTOR"] = notas["DESERTOR"].astype(bool)
notas["ACTIVO"] = notas["ACTIVO"].astype(bool)
notas["DESPLAZADO_VICTIMA_CONFLICTO"] = notas["DESPLAZADO_VICTIMA_CONFLICTO"].astype(bool)
notas["FIRST_GENERATION"] = notas["FIRST_GENERATION"].astype(bool)

print("✅ Variables binarias convertidas a bool correctamente")
# Out:
# Verificando NaN en variables binarias antes de convertir...
#   • GRADUADO: 327 NaN encontrados → Llenando con 0
#   • DESERTOR: 327 NaN encontrados → Llenando con 0
#   • ACTIVO: 327 NaN encontrados → Llenando con 0
#   • DESPLAZADO_VICTIMA_CONFLICTO: 1689990 NaN encontrados → Llenando con 0
#   • FIRST_GENERATION: 934503 NaN encontrados → Llenando con 0
# ✅ NaN llenados con 0 en todas las variables binarias
# ✅ Variables binarias convertidas a bool correctamente

# %%
    # Llenar valores vacíos (NaN, None, espacios vacíos)
    notas['DISCAPACIDAD'] = notas['DISCAPACIDAD'].fillna('Sin discapacidad')
    
    # También llenar strings vacíos o solo con espacios
    notas['DISCAPACIDAD'] = notas['DISCAPACIDAD'].replace('', 'Sin discapacidad')
    notas['DISCAPACIDAD'] = notas['DISCAPACIDAD'].str.strip()  # Quitar espacios
    notas.loc[notas['DISCAPACIDAD'] == '', 'DISCAPACIDAD'] = 'Sin discapacidad'

# %%
notas.DISCAPACIDAD.unique()
# Out:
# array(['Sin discapacidad', 'Movilidad', 'Aprendizaje', 'Visión', 'Otra',
#        'Auditiva', 'Médica'], dtype=object)

# %% [markdown]
# ### Llenar faltantes en estrato

# %%
estrato_faltantes=notas.groupby(['EMPLID_ANÓNIMO'], as_index=False, sort=False).agg({'ESTRATO':'max'})

# %%
estrato_faltantes=estrato_faltantes[estrato_faltantes['ESTRATO'].isna()]

# %%
estrato_faltantes = pd.DataFrame(estrato_faltantes, columns=['EMPLID_ANÓNIMO','ESTRATO'])

# %%
estrato_faltantes.shape
# Out:
# (20009, 2)

# %%
estrato_faltantes.head()
# Out:
#     EMPLID_ANÓNIMO  ESTRATO
# 33           50161     <NA>
# 41           16929     <NA>
# 91           42827     <NA>
# 98           42819     <NA>
# 107          29089     <NA>

# %%
estrato_faltantes['EMPLID_ANÓNIMO'].duplicated().any()
# Out:
# np.False_

# %%
estratos = [1, 2, 3, 4, 5, 6]
# Distribución según tus porcentajes (deben sumar 1)
proporciones = np.array([0.03575, 0.03575, 0.1309, 0.1318, 0.1912, 0.1875])
proporciones = proporciones / proporciones.sum()

# %%
faltantes = estrato_faltantes['EMPLID_ANÓNIMO'].count()
print(f"Valores faltantes: {faltantes}")
# Out:
# Valores faltantes: 20009

# %%
valores_aleatorios = np.random.choice([1, 2, 3, 4, 5, 6], size=faltantes, p=proporciones)

# %%
type(estrato_faltantes)
# Out:
# pandas.core.frame.DataFrame

# %%
estrato_faltantes.columns
# Out:
# Index(['EMPLID_ANÓNIMO', 'ESTRATO'], dtype='object')

# %%
estrato_faltantes.columns = [str(col) for col in estrato_faltantes.columns]

# %%
valores_aleatorios = np.random.choice(
    estratos, 
    size=estrato_faltantes['ESTRATO'].isna().sum(), 
    p=proporciones
).astype(str)  # 🔹 convierte los valores a strings

estrato_faltantes.loc[
    estrato_faltantes['ESTRATO'].isna(), 'ESTRATO'
] = valores_aleatorios

# %%
# 5. Asegurar que la columna quede como entero
estrato_faltantes['ESTRATO'] = estrato_faltantes['ESTRATO'].astype(int)

# %%
# 6. Verificar distribución resultante
print(estrato_faltantes['ESTRATO'].value_counts(normalize=True).round(4))
# Out:
# ESTRATO
# 5    0.2640
# 6    0.2632
# 3    0.1877
# 4    0.1849
# 2    0.0503
# 1    0.0500
# Name: proportion, dtype: float64

# %%
notas=pd.merge(notas,estrato_faltantes[['EMPLID_ANÓNIMO', 'ESTRATO']], on='EMPLID_ANÓNIMO', how='left')

# %%
notas.shape
# Out:
# (2194612, 22)

# %%
notas.head()
# Out:
#   EMPLID_ANÓNIMO NIVEL_ACADEMICO SEMESTRE ID_MATERIA NRO_MATERIA  \
# 0          44693            PREG   2025-1     121031      MU0499
# 1          51524            PREG   2022-2     129738      PT0231
# 2          40012            PREG   2025-1     129703      PT0207
# 3          30416            PREG   2024-2     129703      PT0207
# 4          14977            PREG   2022-1     112801      EC0200
#
#               NOMBRE_MATERIA COD_PROGRAMA             NOMBRE_PROGRAMA  \
# 0  RECITAL PROYECTO DE GRADO           83                      Música
# 1           EMPRESARISMO 001            1  Administración de Negocios
# 2             VALIDACIÓN 001            1  Administración de Negocios
# 3             VALIDACIÓN 001            1  Administración de Negocios
# 4           TRABAJO DE GRADO            3                    Economía
#
#                           ESCUELA NIVEL_ACADÉMICO_CURSO  ... CRÉDITOS  \
# 0  Escuela de Artes y Humanidades                  PREG  ...        6
# 1       Escuela de Administración                  PREG  ...       18
# 2       Escuela de Administración                  PREG  ...       18
# 3       Escuela de Administración                  PREG  ...       18
# 4  E.Finanzas, Economía, Gobierno                  PREG  ...        6
#
#        DISCAPACIDAD  FIRST_GENERATION DESPLAZADO_VICTIMA_CONFLICTO  COHORTE  \
# 0  Sin discapacidad              True                        False   2021-1
# 1  Sin discapacidad             False                        False   2020-1
# 2  Sin discapacidad              True                        False   2019-2
# 3  Sin discapacidad             False                        False   2020-1
# 4  Sin discapacidad             False                        False   2016-1
#
#    DESERTOR GRADUADO  ACTIVO  ESTRATO_x  ESTRATO_y
# 0     False    False    True          4        NaN
# 1     False     True   False          3        NaN
# 2     False    False    True          6        NaN
# 3     False    False    True          5        NaN
# 4     False     True   False          4        NaN
#
# [5 rows x 22 columns]

# %%
notas['ESTRATO'] = notas['ESTRATO_x'].fillna(notas['ESTRATO_y'])
notas.drop(columns=['ESTRATO_x', 'ESTRATO_y'], inplace=True)

# %%
notas.shape
# Out:
# (2194612, 21)

# %%
notas.ESTRATO.unique()
# Out:
# <IntegerArray>
# [4, 3, 6, 5, 2, 1]
# Length: 6, dtype: Int64

# %%
notas.head()
# Out:
#   EMPLID_ANÓNIMO NIVEL_ACADEMICO SEMESTRE ID_MATERIA NRO_MATERIA  \
# 0          44693            PREG   2025-1     121031      MU0499
# 1          51524            PREG   2022-2     129738      PT0231
# 2          40012            PREG   2025-1     129703      PT0207
# 3          30416            PREG   2024-2     129703      PT0207
# 4          14977            PREG   2022-1     112801      EC0200
#
#               NOMBRE_MATERIA COD_PROGRAMA             NOMBRE_PROGRAMA  \
# 0  RECITAL PROYECTO DE GRADO           83                      Música
# 1           EMPRESARISMO 001            1  Administración de Negocios
# 2             VALIDACIÓN 001            1  Administración de Negocios
# 3             VALIDACIÓN 001            1  Administración de Negocios
# 4           TRABAJO DE GRADO            3                    Economía
#
#                           ESCUELA NIVEL_ACADÉMICO_CURSO  ... NOTA  CRÉDITOS  \
# 0  Escuela de Artes y Humanidades                  PREG  ...  4.5         6
# 1       Escuela de Administración                  PREG  ...  4.5        18
# 2       Escuela de Administración                  PREG  ...  5.0        18
# 3       Escuela de Administración                  PREG  ...  4.7        18
# 4  E.Finanzas, Economía, Gobierno                  PREG  ...  3.7         6
#
#        DISCAPACIDAD FIRST_GENERATION  DESPLAZADO_VICTIMA_CONFLICTO  COHORTE  \
# 0  Sin discapacidad             True                         False   2021-1
# 1  Sin discapacidad            False                         False   2020-1
# 2  Sin discapacidad             True                         False   2019-2
# 3  Sin discapacidad            False                         False   2020-1
# 4  Sin discapacidad            False                         False   2016-1
#
#   DESERTOR  GRADUADO  ACTIVO  ESTRATO
# 0    False     False    True        4
# 1    False      True   False        3
# 2    False     False    True        6
# 3    False     False    True        5
# 4    False      True   False        4
#
# [5 rows x 21 columns]

# %%
notas[notas['EMPLID_ANÓNIMO']=='1000'].ESTRATO.unique()
# Out:
# <IntegerArray>
# [1]
# Length: 1, dtype: Int64

# %%
notas[notas['EMPLID_ANÓNIMO']=='1000'].head(5)
# Out:
#       EMPLID_ANÓNIMO NIVEL_ACADEMICO SEMESTRE ID_MATERIA NRO_MATERIA  \
# 29572           1000            PREG   2005-1     118876      IP0195
# 29573           1000            PREG   2005-1     118785      IP0104
# 30344           1000            PREG   2006-1     118791      IP0110
# 30345           1000            PREG   2004-2     126455      ST0319
# 31067           1000            PREG   2005-1     118790      IP0109
#
#                   NOMBRE_MATERIA COD_PROGRAMA           NOMBRE_PROGRAMA  \
# 29572   PRODUCCIÓN SISTEMÁTICA 1           12  Ingeniería de Producción
# 29573                    ENSAYOS           12  Ingeniería de Producción
# 30344  PROCESOS DE MANUFACTURA 2           12  Ingeniería de Producción
# 30345              ESTADÍSTICA 2           12  Ingeniería de Producción
# 31067  PROCESOS DE MANUFACTURA 1           12  Ingeniería de Producción
#
#                              ESCUELA NIVEL_ACADÉMICO_CURSO  ... NOTA  \
# 29572  E Ciencias Aplic e Ingeniería                  PREG  ...  3.0
# 29573  E Ciencias Aplic e Ingeniería                  PREG  ...  3.0
# 30344  E Ciencias Aplic e Ingeniería                  PREG  ...  3.6
# 30345  E Ciencias Aplic e Ingeniería                  PREG  ...  3.6
# 31067  E Ciencias Aplic e Ingeniería                  PREG  ...  3.7
#
#        CRÉDITOS      DISCAPACIDAD FIRST_GENERATION  \
# 29572         4  Sin discapacidad            False
# 29573         4  Sin discapacidad            False
# 30344         4  Sin discapacidad            False
# 30345         4  Sin discapacidad            False
# 31067         4  Sin discapacidad            False
#
#        DESPLAZADO_VICTIMA_CONFLICTO  COHORTE DESERTOR  GRADUADO  ACTIVO  \
# 29572                         False   2002-2    False      True   False
# 29573                         False   2002-2    False      True   False
# 30344                         False   2002-2    False      True   False
# 30345                         False   2002-2    False      True   False
# 31067                         False   2002-2    False      True   False
#
#        ESTRATO
# 29572        1
# 29573        1
# 30344        1
# 30345        1
# 31067        1
#
# [5 rows x 21 columns]

# %% [markdown]
# # 3. ESTADÍSTICAS DESCRIPTIVAS

# %%
def estadisticas_descriptivas(df):
    """
    Genera estadísticas descriptivas del dataset
    """
    print("\n" + "="*80)
    print("ESTADÍSTICAS DESCRIPTIVAS")
    print("="*80)
    
    # Variables numéricas
    print("\n--- Variables Numéricas ---")
    print(df.describe())
    
    # Variables categóricas
    print("\n--- Variables Categóricas ---")
    cat_cols = df.select_dtypes(include=['object']).columns
    for col in cat_cols:
        print(f"\n{col}:")
        print(f"  Valores únicos: {df[col].nunique()}")
        print(f"  Distribución:")
        print(df[col].value_counts().head(10))

# %%
estadisticas_descriptivas(notas)
# Out:
# ================================================================================
# ESTADÍSTICAS DESCRIPTIVAS
# ================================================================================
#
# --- Variables Numéricas ---
#                NOTA      CRÉDITOS    ESTRATO
# count  2.194612e+06  2.194612e+06  2194612.0
# mean   3.857949e+00  3.326536e+00   4.378236
# std    8.155144e-01  2.139776e+00   1.380639
# min    0.000000e+00  1.000000e+00        1.0
# 25%    3.400000e+00  3.000000e+00        3.0
# 50%    4.000000e+00  3.000000e+00        5.0
# 75%    4.400000e+00  3.000000e+00        6.0
# max    5.000000e+00  2.400000e+01        6.0
#
# --- Variables Categóricas ---
#
# NIVEL_ACADEMICO:
#   Valores únicos: 1
#   Distribución:
# NIVEL_ACADEMICO
# PREG    2194612
# Name: count, dtype: int64
#
# SEMESTRE:
#   Valores únicos: 52
#   Distribución:
# SEMESTRE
# 2018-1    52555
# 2019-1    52346
# 2017-1    52042
# 2016-1    51352
# 2020-1    50599
# 2018-2    50192
# 2017-2    49995
# 2025-1    49989
# 2016-2    48824
# 2019-2    48488
# Name: count, dtype: int64
#
# NRO_MATERIA:
#   Valores únicos: 7700
#   Distribución:
# NRO_MATERIA
# DE0084    23776
# OG0591    23078
# PR0312    14403
# HL0591    13667
# CO0133    13612
# CO0135    13562
# EC0101    12888
# FI0116    12213
# GP0039    11346
# DE0119    11223
# Name: count, dtype: int64
#
# NOMBRE_MATERIA:
#   Valores únicos: 3591
#   Distribución:
# NOMBRE_MATERIA
# CONSTITUCIÓN Y SOCIEDAD (NFI)    23776
# INICIAT. Y CULT. EMPRL. (NFI)    23079
# FUNDAMENTOS DE CONTABILIDAD      22468
# MATEMÁTICAS FINANCIERAS          20285
# ÁLGEBRA LINEAL                   19630
# CÁLCULO DIFERENCIAL              17059
# MATEMÁTICAS 1                    15570
# ANÁLISIS TEXTUAL (NFI)           15502
# ECONOMÍA INTERNACIONAL           15473
# ECOLOGÍA                         14538
# Name: count, dtype: int64
#
# NOMBRE_PROGRAMA:
#   Valores únicos: 32
#   Distribución:
# NOMBRE_PROGRAMA
# Administración de Negocios       546457
# Negocios Internacionales         264676
# Ingeniería Diseño de Producto    156502
# Ingeniería de Sistemas           133712
# Derecho                          131455
# Ingeniería Mecánica              129170
# Ingeniería Civil                 128058
# Ingeniería de Producción         117577
# Comunicación Social               90867
# Mercadeo                          79284
# Name: count, dtype: int64
#
# ESCUELA:
#   Valores únicos: 5
#   Distribución:
# ESCUELA
# Escuela de Administración         933521
# E Ciencias Aplic e Ingeniería     811385
# Escuela de Artes y Humanidades    190951
# Escuela de Derecho                131455
# E.Finanzas, Economía, Gobierno    127300
# Name: count, dtype: int64
#
# NIVEL_ACADÉMICO_CURSO:
#   Valores únicos: 4
#   Distribución:
# NIVEL_ACADÉMICO_CURSO
# PREG    2194520
# MSTR         46
# DOCT         43
# ESPE          3
# Name: count, dtype: int64
#
# SISTEMA_CALIFICACION:
#   Valores únicos: 2
#   Distribución:
# SISTEMA_CALIFICACION
# C30    2194529
# C35         83
# Name: count, dtype: int64
#
# DISCAPACIDAD:
#   Valores únicos: 7
#   Distribución:
# DISCAPACIDAD
# Sin discapacidad    2164256
# Visión                24750
# Auditiva               2816
# Movilidad              1557
# Médica                  512
# Aprendizaje             469
# Otra                    252
# Name: count, dtype: int64
#
# COHORTE:
#   Valores únicos: 87
#   Distribución:
# COHORTE
# 2016-1    78797
# 2015-1    70130
# 2017-1    68428
# 2014-1    63642
# 2018-1    61499
# 2001-1    59861
# 2002-1    59552
# 2003-1    58636
# 2012-1    58627
# 2011-1    58498
# Name: count, dtype: int64

# %% [markdown]
# # 4. ANÁLISIS DE NOTAS

# %%
def analizar_notas(df):
    """
    Análisis detallado de las calificaciones
    """
    print("\n" + "="*80)
    print("ANÁLISIS DE CALIFICACIONES (NOTA)")
    print("="*80)
    
    print("\n--- Estadísticas de NOTA ---")
    print(df['NOTA'].describe())
    
    print(f"\nNota promedio general: {df['NOTA'].mean():.2f}")
    print(f"Mediana de notas: {df['NOTA'].median():.2f}")
    print(f"Desviación estándar: {df['NOTA'].std():.2f}")
    
    # Crear categorías de notas
    df['CATEGORIA_NOTA'] = pd.cut(df['NOTA'], 
                                   bins=[0, 2.5, 3.0, 3.5, 4.0, 5.0],
                                   labels=['Muy Bajo (0-2.5)', 'Bajo (2.5-3.0)', 
                                          'Medio (3.0-3.5)', 'Bueno (3.5-4.0)', 
                                          'Excelente (4.0-5.0)'])
    
    print("\n--- Distribución por Categoría ---")
    print(df['CATEGORIA_NOTA'].value_counts().sort_index())
    
    # Visualizaciones
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    
    # Histograma
    axes[0, 0].hist(df['NOTA'], bins=50, edgecolor='black', alpha=0.7)
    axes[0, 0].axvline(df['NOTA'].mean(), color='red', linestyle='--', label=f'Media: {df["NOTA"].mean():.2f}')
    axes[0, 0].axvline(df['NOTA'].median(), color='green', linestyle='--', label=f'Mediana: {df["NOTA"].median():.2f}')
    axes[0, 0].set_xlabel('Nota')
    axes[0, 0].set_ylabel('Frecuencia')
    axes[0, 0].set_title('Distribución de Notas')
    axes[0, 0].legend()
    
    # Boxplot
    axes[0, 1].boxplot(df['NOTA'].dropna())
    axes[0, 1].set_ylabel('Nota')
    axes[0, 1].set_title('Boxplot de Notas')
    
    # Notas por sistema de calificación
    df.groupby('SISTEMA_CALIFICACION')['NOTA'].mean().plot(kind='bar', ax=axes[1, 0])
    axes[1, 0].set_xlabel('Sistema de Calificación')
    axes[1, 0].set_ylabel('Nota Promedio')
    axes[1, 0].set_title('Nota Promedio por Sistema de Calificación')
    axes[1, 0].tick_params(axis='x', rotation=0)
    
    # Categorías de notas
    df['CATEGORIA_NOTA'].value_counts().sort_index().plot(kind='bar', ax=axes[1, 1])
    axes[1, 1].set_xlabel('Categoría')
    axes[1, 1].set_ylabel('Cantidad')
    axes[1, 1].set_title('Distribución por Categoría de Nota')
    axes[1, 1].tick_params(axis='x', rotation=45)
    
    plt.tight_layout()
    plt.show()
    
    # Tasa de aprobación
    if 'SISTEMA_CALIFICACION' in df.columns:
        df['APROBADO'] = np.where(
            (df['SISTEMA_CALIFICACION'] == 'C30') & (df['NOTA'] >= 3.0), 'Sí',
            np.where((df['SISTEMA_CALIFICACION'] == 'C35') & (df['NOTA'] >= 3.5), 'Sí', 'No')
        )
        tasa_aprobacion = (df['APROBADO'] == 'Sí').sum() / len(df) * 100
        print(f"\nTasa de aprobación general: {tasa_aprobacion:.2f}%")

# %%
analizar_notas(notas)
# Out:
# ================================================================================
# ANÁLISIS DE CALIFICACIONES (NOTA)
# ================================================================================
#
# --- Estadísticas de NOTA ---
# count    2.194612e+06
# mean     3.857949e+00
# std      8.155144e-01
# min      0.000000e+00
# 25%      3.400000e+00
# 50%      4.000000e+00
# 75%      4.400000e+00
# max      5.000000e+00
# Name: NOTA, dtype: float64
#
# Nota promedio general: 3.86
# Mediana de notas: 4.00
# Desviación estándar: 0.82
#
# --- Distribución por Categoría ---
# CATEGORIA_NOTA
# Muy Bajo (0-2.5)        83848
# Bajo (2.5-3.0)         173009
# Medio (3.0-3.5)        396670
# Bueno (3.5-4.0)        529545
# Excelente (4.0-5.0)    996092
# Name: count, dtype: int64
# Tasa de aprobación general: 92.57%

# %% [markdown]
# # 5. ANÁLISIS TEMPORAL

# %%
def analizar_temporal(df):
    """
    Análisis de la evolución temporal
    """
    print("\n" + "="*80)
    print("ANÁLISIS TEMPORAL")
    print("="*80)
    
    print(f"\nRango de semestres: {df['SEMESTRE'].min()} - {df['SEMESTRE'].max()}")
    print(f"Número de semestres únicos: {df['SEMESTRE'].nunique()}")
    
    # Evolución de notas por semestre
    notas_por_semestre = df.groupby('SEMESTRE')['NOTA'].agg(['mean', 'median', 'std']).reset_index()
    notas_por_semestre.columns = ['SEMESTRE', 'PROMEDIO', 'MEDIANA', 'DESV_STD']
    
    # Estudiantes únicos por semestre
    estudiantes_por_semestre = df.groupby('SEMESTRE')['EMPLID_ANÓNIMO'].nunique().reset_index()
    estudiantes_por_semestre.columns = ['SEMESTRE', 'ESTUDIANTES_UNICOS']
    
    # Materias únicas por semestre
    materias_por_semestre = df.groupby('SEMESTRE')['NRO_MATERIA'].nunique().reset_index()
    materias_por_semestre.columns = ['SEMESTRE', 'MATERIAS_UNICAS']
    
    # Número de registros por semestre
    registros_por_semestre = df.groupby('SEMESTRE').size().reset_index()
    registros_por_semestre.columns = ['SEMESTRE', 'REGISTROS']
    
    # Paso para las etiquetas (mostrar ~15 etiquetas)
    step = max(1, len(notas_por_semestre) // 15)
    
    # ========================================================================
    # GRÁFICA 1: Nota promedio y mediana por semestre con etiquetas
    # ========================================================================
    print("\n" + "-"*80)
    print("GRÁFICA 1: EVOLUCIÓN DE NOTAS POR SEMESTRE")
    print("-"*80)
    
    fig1, ax1 = plt.subplots(figsize=(16, 6))
    ax1.plot(notas_por_semestre['SEMESTRE'], notas_por_semestre['PROMEDIO'], 
             marker='o', label='Promedio', linewidth=2.5, markersize=5, color='#2E86AB')
    ax1.plot(notas_por_semestre['SEMESTRE'], notas_por_semestre['MEDIANA'], 
             marker='s', label='Mediana', linewidth=2.5, markersize=5, color='#A23B72')
    
    # Agregar etiquetas de datos
    for i in range(0, len(notas_por_semestre), step):
        ax1.annotate(f'{notas_por_semestre.iloc[i]["PROMEDIO"]:.2f}', 
                    (notas_por_semestre.iloc[i]['SEMESTRE'], notas_por_semestre.iloc[i]['PROMEDIO']),
                    textcoords="offset points", xytext=(0,8), ha='center', fontsize=8, 
                    color='#2E86AB', fontweight='bold')
    
    ax1.set_xlabel('Semestre', fontsize=12, fontweight='bold')
    ax1.set_ylabel('Nota', fontsize=12, fontweight='bold')
    ax1.set_title('Evolución de Notas por Semestre', fontsize=14, fontweight='bold', pad=15)
    ax1.legend(fontsize=11)
    ax1.grid(True, alpha=0.3, linestyle='--')
    ax1.tick_params(axis='x', rotation=45, labelsize=9)
    ax1.tick_params(axis='y', labelsize=10)
    plt.tight_layout()
    plt.show()
    
    # Tabla de datos
    print("\nTabla de Datos - Notas por Semestre:")
    tabla_notas = notas_por_semestre.copy()
    tabla_notas['PROMEDIO'] = tabla_notas['PROMEDIO'].round(2)
    tabla_notas['MEDIANA'] = tabla_notas['MEDIANA'].round(2)
    tabla_notas['DESV_STD'] = tabla_notas['DESV_STD'].round(2)
    print(tabla_notas.to_string(index=False))
    
    # ========================================================================
    # GRÁFICA 2: Estudiantes únicos por semestre
    # ========================================================================
    print("\n" + "-"*80)
    print("GRÁFICA 2: ESTUDIANTES ÚNICOS POR SEMESTRE")
    print("-"*80)
    
    fig2, ax2 = plt.subplots(figsize=(16, 6))
    ax2.plot(estudiantes_por_semestre['SEMESTRE'], estudiantes_por_semestre['ESTUDIANTES_UNICOS'],
             marker='o', color='#06A77D', linewidth=2.5, markersize=5)
    ax2.fill_between(estudiantes_por_semestre['SEMESTRE'], 
                     estudiantes_por_semestre['ESTUDIANTES_UNICOS'], 
                     alpha=0.3, color='#06A77D')
    
    # Agregar etiquetas de datos
    for i in range(0, len(estudiantes_por_semestre), step):
        ax2.annotate(f'{estudiantes_por_semestre.iloc[i]["ESTUDIANTES_UNICOS"]:,}', 
                    (estudiantes_por_semestre.iloc[i]['SEMESTRE'], 
                     estudiantes_por_semestre.iloc[i]['ESTUDIANTES_UNICOS']),
                    textcoords="offset points", xytext=(0,8), ha='center', fontsize=8,
                    color='#06A77D', fontweight='bold')
    
    ax2.set_xlabel('Semestre', fontsize=12, fontweight='bold')
    ax2.set_ylabel('Número de Estudiantes Únicos', fontsize=12, fontweight='bold')
    ax2.set_title('Estudiantes Únicos por Semestre', fontsize=14, fontweight='bold', pad=15)
    ax2.grid(True, alpha=0.3, linestyle='--')
    ax2.tick_params(axis='x', rotation=45, labelsize=9)
    ax2.tick_params(axis='y', labelsize=10)
    plt.tight_layout()
    plt.show()
    
    # Tabla de datos
    print("\nTabla de Datos - Estudiantes Únicos por Semestre:")
    print(estudiantes_por_semestre.to_string(index=False))
    
    # ========================================================================
    # GRÁFICA 3: Materias únicas por semestre
    # ========================================================================
    print("\n" + "-"*80)
    print("GRÁFICA 3: MATERIAS ÚNICAS OFRECIDAS POR SEMESTRE")
    print("-"*80)
    
    fig3, ax3 = plt.subplots(figsize=(16, 6))
    ax3.plot(materias_por_semestre['SEMESTRE'], materias_por_semestre['MATERIAS_UNICAS'],
             marker='s', color='#9D4EDD', linewidth=2.5, markersize=5)
    ax3.fill_between(materias_por_semestre['SEMESTRE'], 
                     materias_por_semestre['MATERIAS_UNICAS'], 
                     alpha=0.3, color='#9D4EDD')
    
    # Agregar etiquetas de datos
    for i in range(0, len(materias_por_semestre), step):
        ax3.annotate(f'{materias_por_semestre.iloc[i]["MATERIAS_UNICAS"]:,}', 
                    (materias_por_semestre.iloc[i]['SEMESTRE'], 
                     materias_por_semestre.iloc[i]['MATERIAS_UNICAS']),
                    textcoords="offset points", xytext=(0,8), ha='center', fontsize=8,
                    color='#9D4EDD', fontweight='bold')
    
    ax3.set_xlabel('Semestre', fontsize=12, fontweight='bold')
    ax3.set_ylabel('Número de Materias Únicas', fontsize=12, fontweight='bold')
    ax3.set_title('Materias Únicas Ofrecidas por Semestre', fontsize=14, fontweight='bold', pad=15)
    ax3.grid(True, alpha=0.3, linestyle='--')
    ax3.tick_params(axis='x', rotation=45, labelsize=9)
    ax3.tick_params(axis='y', labelsize=10)
    plt.tight_layout()
    plt.show()
    
    # Tabla de datos
    print("\nTabla de Datos - Materias Únicas por Semestre:")
    print(materias_por_semestre.to_string(index=False))
    
    # ========================================================================
    # GRÁFICA 4: Número de registros por semestre
    # ========================================================================
    print("\n" + "-"*80)
    print("GRÁFICA 4: TOTAL DE REGISTROS POR SEMESTRE")
    print("-"*80)
    
    fig4, ax4 = plt.subplots(figsize=(16, 6))
    ax4.bar(registros_por_semestre['SEMESTRE'], registros_por_semestre['REGISTROS'], 
            color='#F07167', alpha=0.8, edgecolor='darkred', linewidth=0.5)
    
    # Agregar etiquetas de datos
    for i in range(0, len(registros_por_semestre), step):
        ax4.text(registros_por_semestre.iloc[i]['SEMESTRE'], 
                registros_por_semestre.iloc[i]['REGISTROS'],
                f'{registros_por_semestre.iloc[i]["REGISTROS"]:,}',
                ha='center', va='bottom', fontsize=8, fontweight='bold', color='darkred')
    
    ax4.set_xlabel('Semestre', fontsize=12, fontweight='bold')
    ax4.set_ylabel('Número de Registros', fontsize=12, fontweight='bold')
    ax4.set_title('Total de Registros por Semestre', fontsize=14, fontweight='bold', pad=15)
    ax4.tick_params(axis='x', rotation=45, labelsize=9)
    ax4.tick_params(axis='y', labelsize=10)
    ax4.grid(True, alpha=0.3, axis='y', linestyle='--')
    plt.tight_layout()
    plt.show()
    
    # Tabla de datos
    print("\nTabla de Datos - Registros por Semestre:")
    print(registros_por_semestre.to_string(index=False))
    
    # ========================================================================
    # ESTADÍSTICAS GENERALES
    # ========================================================================
    # Estadísticas por año
    df['AÑO'] = df['SEMESTRE'].astype(str).str[:4]
    print("\n" + "="*80)
    print("ESTADÍSTICAS GENERALES")
    print("="*80)
    print("\n--- Registros por Año ---")
    print(df['AÑO'].value_counts().sort_index())
    
    # Estadísticas adicionales
    print("\n--- Estadísticas por Semestre ---")
    print(f"Promedio de estudiantes únicos por semestre: {estudiantes_por_semestre['ESTUDIANTES_UNICOS'].mean():.0f}")
    print(f"Promedio de materias únicas por semestre: {materias_por_semestre['MATERIAS_UNICAS'].mean():.0f}")
    print(f"Promedio de registros por semestre: {registros_por_semestre['REGISTROS'].mean():.0f}")
    
    # Semestre con más estudiantes
    max_estudiantes = estudiantes_por_semestre.loc[estudiantes_por_semestre['ESTUDIANTES_UNICOS'].idxmax()]
    print(f"\nSemestre con más estudiantes: {max_estudiantes['SEMESTRE']} ({max_estudiantes['ESTUDIANTES_UNICOS']:,} estudiantes)")
    
    # Semestre con más materias
    max_materias = materias_por_semestre.loc[materias_por_semestre['MATERIAS_UNICAS'].idxmax()]
    print(f"Semestre con más materias ofrecidas: {max_materias['SEMESTRE']} ({max_materias['MATERIAS_UNICAS']:,} materias)")

# %%
analizar_temporal(notas)
# Out:
# ================================================================================
# ANÁLISIS TEMPORAL
# ================================================================================
#
# Rango de semestres: 2000-1 - 2025-2
# Número de semestres únicos: 52
#
# --------------------------------------------------------------------------------
# GRÁFICA 1: EVOLUCIÓN DE NOTAS POR SEMESTRE
# --------------------------------------------------------------------------------
# Tabla de Datos - Notas por Semestre:
# SEMESTRE  PROMEDIO  MEDIANA  DESV_STD
#   2000-1      3.71      3.8      0.78
#   2000-2      3.75      3.8      0.77
#   2001-1      3.74      3.8      0.75
#   2001-2      3.73      3.8      0.77
#   2002-1      3.74      3.8      0.78
#   2002-2      3.72      3.8      0.76
#   2003-1      3.69      3.8      0.78
#   2003-2      3.66      3.7      0.78
#   2004-1      3.71      3.8      0.80
#   2004-2      3.72      3.8      0.74
#   2005-1      3.74      3.8      0.79
#   2005-2      3.75      3.8      0.77
#   2006-1      3.70      3.8      0.89
#   2006-2      3.75      3.8      0.81
#   2007-1      3.75      3.9      0.83
#   2007-2      3.76      3.9      0.81
#   2008-1      3.80      3.9      0.83
#   2008-2      3.77      3.9      0.83
#   2009-1      3.79      3.9      0.83
#   2009-2      3.80      3.9      0.80
#   2010-1      3.82      3.9      0.79
#   2010-2      3.79      3.9      0.81
#   2011-1      3.82      3.9      0.79
#   2011-2      3.80      3.9      0.81
#   2012-1      3.81      3.9      0.81
#   2012-2      3.81      3.9      0.80
#   2013-1      3.84      3.9      0.80
#   2013-2      3.82      3.9      0.81
#   2014-1      3.86      3.9      0.79
#   2014-2      3.84      3.9      0.80
#   2015-1      3.87      4.0      0.79
#   2015-2      3.85      3.9      0.81
#   2016-1      3.87      4.0      0.80
#   2016-2      3.85      3.9      0.82
#   2017-1      3.87      4.0      0.81
#   2017-2      3.85      3.9      0.81
#   2018-1      3.88      4.0      0.81
#   2018-2      3.87      4.0      0.82
#   2019-1      3.85      4.0      0.89
#   2019-2      3.89      4.0      0.83
#   2020-1      4.11      4.2      0.72
#   2020-2      4.11      4.3      0.77
#   2021-1      4.12      4.3      0.76
#   2021-2      4.01      4.2      0.84
#   2022-1      4.02      4.2      0.83
#   2022-2      4.01      4.2      0.84
#   2023-1      4.03      4.2      0.85
#   2023-2      4.03      4.2      0.83
#   2024-1      4.05      4.2      0.83
#   2024-2      4.05      4.2      0.83
#   2025-1      4.10      4.3      0.82
#   2025-2      4.58      4.6      0.35
#
# --------------------------------------------------------------------------------
# GRÁFICA 2: ESTUDIANTES ÚNICOS POR SEMESTRE
# --------------------------------------------------------------------------------
# Tabla de Datos - Estudiantes Únicos por Semestre:
# SEMESTRE  ESTUDIANTES_UNICOS
#   2000-1                6659
#   2000-2                6494
#   2001-1                6948
#   2001-2                6674
#   2002-1                7152
#   2002-2                7126
#   2003-1                7412
#   2003-2                7296
#   2004-1                7368
#   2004-2                7250
#   2005-1                7318
#   2005-2                7411
#   2006-1                7565
#   2006-2                7466
#   2007-1                7723
#   2007-2                7558
#   2008-1                8041
#   2008-2                7836
#   2009-1                8116
#   2009-2                8002
#   2010-1                8381
#   2010-2                8345
#   2011-1                8900
#   2011-2                8636
#   2012-1                9056
#   2012-2                8767
#   2013-1                9170
#   2013-2                8947
#   2014-1                9325
#   2014-2                9240
#   2015-1                9899
#   2015-2                9756
#   2016-1               10539
#   2016-2               10280
#   2017-1               10804
#   2017-2               10627
#   2018-1               10894
#   2018-2               10605
#   2019-1               10604
#   2019-2               10096
#   2020-1               10139
#   2020-2                9561
#   2021-1                9823
#   2021-2                9061
#   2022-1                9272
#   2022-2                8945
#   2023-1                9072
#   2023-2                8996
#   2024-1                9285
#   2024-2                9236
#   2025-1                9414
#   2025-2                 167
#
# --------------------------------------------------------------------------------
# GRÁFICA 3: MATERIAS ÚNICAS OFRECIDAS POR SEMESTRE
# --------------------------------------------------------------------------------
# Tabla de Datos - Materias Únicas por Semestre:
# SEMESTRE  MATERIAS_UNICAS
#   2000-1              755
#   2000-2              813
#   2001-1              880
#   2001-2              951
#   2002-1              984
#   2002-2             1098
#   2003-1             1085
#   2003-2             1165
#   2004-1             1166
#   2004-2             1273
#   2005-1             1231
#   2005-2             1312
#   2006-1             1294
#   2006-2             1337
#   2007-1             1271
#   2007-2             1366
#   2008-1             1410
#   2008-2             1425
#   2009-1             1354
#   2009-2             1332
#   2010-1             1228
#   2010-2             1200
#   2011-1             1148
#   2011-2             1114
#   2012-1             1086
#   2012-2             1048
#   2013-1             1011
#   2013-2             1017
#   2014-1              995
#   2014-2             1023
#   2015-1             1041
#   2015-2             1052
#   2016-1             1075
#   2016-2             1074
#   2017-1             1111
#   2017-2             1105
#   2018-1             1124
#   2018-2             1136
#   2019-1             1156
#   2019-2             1155
#   2020-1             1177
#   2020-2             1143
#   2021-1             1193
#   2021-2             1203
#   2022-1             1212
#   2022-2             1286
#   2023-1             1314
#   2023-2             1340
#   2024-1             1360
#   2024-2             1445
#   2025-1             1488
#   2025-2               30
#
# --------------------------------------------------------------------------------
# GRÁFICA 4: TOTAL DE REGISTROS POR SEMESTRE
# --------------------------------------------------------------------------------
# Tabla de Datos - Registros por Semestre:
# SEMESTRE  REGISTROS
#   2000-1      34931
#   2000-2      34374
#   2001-1      37661
#   2001-2      35785
#   2002-1      38567
#   2002-2      38880
#   2003-1      40635
#   2003-2      40845
#   2004-1      39213
#   2004-2      37754
#   2005-1      37544
#   2005-2      38243
#   2006-1      38470
#   2006-2      37579
#   2007-1      38996
#   2007-2      37526
#   2008-1      40013
#   2008-2      38335
#   2009-1      40571
#   2009-2      38216
#   2010-1      40660
#   2010-2      38741
#   2011-1      42536
#   2011-2      39399
#   2012-1      43581
#   2012-2      40361
#   2013-1      44083
#   2013-2      41759
#   2014-1      45356
#   2014-2      43067
#   2015-1      47876
#   2015-2      46208
#   2016-1      51352
#   2016-2      48824
#   2017-1      52042
#   2017-2      49995
#   2018-1      52555
#   2018-2      50192
#   2019-1      52346
#   2019-2      48488
#   2020-1      50599
#   2020-2      45447
#   2021-1      46597
#   2021-2      42926
#   2022-1      44596
#   2022-2      43600
#   2023-1      45678
#   2023-2      45070
#   2024-1      47964
#   2024-2      48385
#   2025-1      49989
#   2025-2        202
#
# ================================================================================
# ESTADÍSTICAS GENERALES
# ================================================================================
#
# --- Registros por Año ---
# AÑO
# 2000     69305
# 2001     73446
# 2002     77447
# 2003     81480
# 2004     76967
# 2005     75787
# 2006     76049
# 2007     76522
# 2008     78348
# 2009     78787
# 2010     79401
# 2011     81935
# 2012     83942
# 2013     85842
# 2014     88423
# 2015     94084
# 2016    100176
# 2017    102037
# 2018    102747
# 2019    100834
# 2020     96046
# 2021     89523
# 2022     88196
# 2023     90748
# 2024     96349
# 2025     50191
# Name: count, dtype: int64
#
# --- Estadísticas por Semestre ---
# Promedio de estudiantes únicos por semestre: 8524
# Promedio de materias únicas por semestre: 1146
# Promedio de registros por semestre: 42204
#
# Semestre con más estudiantes: 2018-1 (10,894 estudiantes)
# Semestre con más materias ofrecidas: 2025-1 (1,488 materias)

# %% [markdown]
# # 6. ANÁLISIS POR ESCUELAS Y PROGRAMAS

# %%
def analizar_escuelas_programas(df):
    """
    Análisis por escuelas y programas académicos
    """
    print("\n" + "="*80)
    print("ANÁLISIS POR ESCUELAS Y PROGRAMAS")
    print("="*80)
    
    # Análisis por escuela
    print("\n--- Distribución por ESCUELA ---")
    estudiantes_por_escuela = df.groupby('ESCUELA')['EMPLID_ANÓNIMO'].nunique()
    print(estudiantes_por_escuela)
    
    notas_por_escuela = df.groupby('ESCUELA').agg({
        'NOTA': ['mean', 'median'],
        'EMPLID_ANÓNIMO': 'nunique'
    }).round(2)
    notas_por_escuela.columns = ['mean', 'median', 'estudiantes']
    notas_por_escuela = notas_por_escuela.sort_values('mean', ascending=False)
    print("\n--- Estadísticas de Notas por ESCUELA ---")
    print(notas_por_escuela)
    
    # Visualizaciones
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    
    # Notas promedio por escuela
    notas_por_escuela['mean'].plot(kind='barh', ax=axes[0, 0], color='skyblue')
    axes[0, 0].set_xlabel('Nota Promedio')
    axes[0, 0].set_title('Nota Promedio por ESCUELA')
    
    # Distribución de estudiantes únicos por escuela
    estudiantes_por_escuela.plot(kind='pie', ax=axes[0, 1], autopct='%1.1f%%')
    axes[0, 1].set_title('Distribución de Estudiantes Únicos por ESCUELA')
    axes[0, 1].set_ylabel('')
    
    # Top 10 programas con más estudiantes únicos
    top_programas = df.groupby('NOMBRE_PROGRAMA')['EMPLID_ANÓNIMO'].nunique().nlargest(10)
    top_programas.plot(kind='barh', ax=axes[1, 0], color='mediumseagreen')
    axes[1, 0].set_xlabel('Número de Estudiantes Únicos')
    axes[1, 0].set_title('Top 10 Programas con Más Estudiantes Únicos')
    
    # Boxplot de notas por escuela
    df.boxplot(column='NOTA', by='ESCUELA', ax=axes[1, 1])
    axes[1, 1].set_xlabel('ESCUELA')
    axes[1, 1].set_ylabel('Nota')
    axes[1, 1].set_title('Distribución de Notas por ESCUELA')
    plt.suptitle('')
    
    plt.tight_layout()
    plt.show()
    
    # Top y bottom 10 programas por nota promedio
    notas_por_programa = df.groupby('NOMBRE_PROGRAMA').agg({
        'NOTA': 'mean',
        'EMPLID_ANÓNIMO': 'nunique'
    })
    notas_por_programa.columns = ['mean', 'estudiantes']
    notas_por_programa = notas_por_programa[notas_por_programa['estudiantes'] >= 50]  # Filtrar programas con al menos 50 estudiantes
    
    print("\n--- Top 10 Programas con Mejor Nota Promedio (mínimo 50 estudiantes) ---")
    print(notas_por_programa.nlargest(10, 'mean').round(2))
    
    print("\n--- Top 10 Programas con Menor Nota Promedio (mínimo 50 estudiantes) ---")
    print(notas_por_programa.nsmallest(10, 'mean').round(2))

# %%
analizar_escuelas_programas(notas)
# Out:
# ================================================================================
# ANÁLISIS POR ESCUELAS Y PROGRAMAS
# ================================================================================
#
# --- Distribución por ESCUELA ---
# ESCUELA
# E Ciencias Aplic e Ingeniería     21826
# E.Finanzas, Economía, Gobierno     4512
# Escuela de Administración         26579
# Escuela de Artes y Humanidades     5110
# Escuela de Derecho                 3633
# Name: EMPLID_ANÓNIMO, dtype: int64
#
# --- Estadísticas de Notas por ESCUELA ---
#                                 mean  median  estudiantes
# ESCUELA
# Escuela de Artes y Humanidades  4.15     4.3         5110
# E.Finanzas, Economía, Gobierno  3.90     4.0         4512
# Escuela de Derecho              3.88     4.0         3633
# E Ciencias Aplic e Ingeniería   3.82     3.9        21826
# Escuela de Administración       3.82     3.9        26579
# --- Top 10 Programas con Mejor Nota Promedio (mínimo 50 estudiantes) ---
#                        mean  estudiantes
# NOMBRE_PROGRAMA
# Literatura             4.34          146
# Música                 4.34          899
# Diseño Interactivo     4.21          505
# Nivelatorio de Música  4.16          491
# Psicología             4.13         1050
# Ingeniería Matemática  4.09          572
# Comunicación Social    4.06         2462
# Ingeniería Agronómica  4.04          173
# Mercadeo               4.01         2643
# Ciencias Políticas     3.98          904
#
# --- Top 10 Programas con Menor Nota Promedio (mínimo 50 estudiantes) ---
#                                 mean  estudiantes
# NOMBRE_PROGRAMA
# Geología                        3.73          925
# Administración de Negocios      3.73        16163
# Ingeniería Civil                3.74         3352
# Ingeniería Civil - Llanogrande  3.74           52
# Administración de Negocios Llg  3.75          195
# Ingeniería de Sistemas Llg      3.76           52
# Ingeniería Mecánica             3.76         3552
# Ingeniería de Sistemas          3.80         4569
# Ingeniería de Producción        3.83         2922
# Economía                        3.83         2547

# %% [markdown]
# # 7. ANÁLISIS DE CARACTERÍSTICAS DEMOGRÁFICAS

# %%
def analizar_demografico(df):
    """
    Análisis de características demográficas y socioeconómicas
    """
    print("\n" + "="*80)
    print("ANÁLISIS DEMOGRÁFICO Y SOCIOECONÓMICO")
    print("="*80)
    
    total_registros = len(df)
    
    # Análisis por estrato
    if 'ESTRATO' in df.columns:
        print("\n--- Distribución por ESTRATO ---")
        dist_estrato = df['ESTRATO'].value_counts().sort_index()
        pct_estrato = (dist_estrato / total_registros * 100).round(2)
        tabla_estrato = pd.DataFrame({
            'Count': dist_estrato,
            'Porcentaje (%)': pct_estrato
        })
        print(tabla_estrato)
        
        notas_por_estrato = df.groupby('ESTRATO')['NOTA'].agg(['mean', 'median', 'count']).round(2)
        notas_por_estrato['porcentaje'] = (notas_por_estrato['count'] / total_registros * 100).round(2)
        print("\n--- Notas por ESTRATO ---")
        print(notas_por_estrato)
    
    # Análisis First Generation
    if 'FIRST_GENERATION' in df.columns:
        print("\n--- First Generation ---")
        dist_first_gen = df['FIRST_GENERATION'].value_counts()
        pct_first_gen = (dist_first_gen / total_registros * 100).round(2)
        tabla_first_gen = pd.DataFrame({
            'Count': dist_first_gen,
            'Porcentaje (%)': pct_first_gen
        })
        print(tabla_first_gen)
        
        notas_first_gen = df.groupby('FIRST_GENERATION')['NOTA'].agg(['mean', 'count']).round(2)
        notas_first_gen['porcentaje'] = (notas_first_gen['count'] / total_registros * 100).round(2)
        print("\n--- Notas por First Generation ---")
        print(notas_first_gen)
    
    # Análisis Discapacidad
    if 'DISCAPACIDAD' in df.columns:
        print("\n--- Discapacidad ---")
        dist_discapacidad = df['DISCAPACIDAD'].value_counts()
        pct_discapacidad = (dist_discapacidad / total_registros * 100).round(2)
        tabla_discapacidad = pd.DataFrame({
            'Count': dist_discapacidad,
            'Porcentaje (%)': pct_discapacidad
        })
        print(tabla_discapacidad)
        
        if df['DISCAPACIDAD'].notna().sum() > 0:
            notas_discapacidad = df.groupby('DISCAPACIDAD')['NOTA'].agg(['mean', 'count']).round(2)
            notas_discapacidad['porcentaje'] = (notas_discapacidad['count'] / total_registros * 100).round(2)
            print("\n--- Notas por Tipo de Discapacidad ---")
            print(notas_discapacidad)
    
    # Análisis Desplazados
    if 'DESPLAZADO_VICTIMA_CONFLICTO' in df.columns:
        print("\n--- Desplazados Víctimas del Conflicto ---")
        dist_desplazados = df['DESPLAZADO_VICTIMA_CONFLICTO'].value_counts()
        pct_desplazados = (dist_desplazados / total_registros * 100).round(2)
        tabla_desplazados = pd.DataFrame({
            'Count': dist_desplazados,
            'Porcentaje (%)': pct_desplazados
        })
        print(tabla_desplazados)
        
        notas_desplazados = df.groupby('DESPLAZADO_VICTIMA_CONFLICTO')['NOTA'].agg(['mean', 'count']).round(2)
        notas_desplazados['porcentaje'] = (notas_desplazados['count'] / total_registros * 100).round(2)
        print("\n--- Notas por Condición de Desplazamiento ---")
        print(notas_desplazados)
    
    # Visualizaciones
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    
    # Notas por estrato
    if 'ESTRATO' in df.columns:
        df.groupby('ESTRATO')['NOTA'].mean().plot(kind='bar', ax=axes[0, 0], color='coral')
        axes[0, 0].set_xlabel('ESTRATO')
        axes[0, 0].set_ylabel('Nota Promedio')
        axes[0, 0].set_title('Nota Promedio por ESTRATO')
        axes[0, 0].tick_params(axis='x', rotation=0)
    
    # Notas por First Generation
    if 'FIRST_GENERATION' in df.columns:
        df.groupby('FIRST_GENERATION')['NOTA'].mean().plot(kind='bar', ax=axes[0, 1], color='lightgreen')
        axes[0, 1].set_xlabel('First Generation')
        axes[0, 1].set_ylabel('Nota Promedio')
        axes[0, 1].set_title('Nota Promedio por First Generation')
        axes[0, 1].tick_params(axis='x', rotation=0)
    
    # Distribución por estrato
    if 'ESTRATO' in df.columns:
        df['ESTRATO'].value_counts().sort_index().plot(kind='bar', ax=axes[1, 0], color='skyblue')
        axes[1, 0].set_xlabel('ESTRATO')
        axes[1, 0].set_ylabel('Cantidad de Registros')
        axes[1, 0].set_title('Distribución de Registros por ESTRATO')
        axes[1, 0].tick_params(axis='x', rotation=0)
    
    # Boxplot estrato vs nota
    if 'ESTRATO' in df.columns:
        df.boxplot(column='NOTA', by='ESTRATO', ax=axes[1, 1])
        axes[1, 1].set_xlabel('ESTRATO')
        axes[1, 1].set_ylabel('Nota')
        axes[1, 1].set_title('Distribución de Notas por ESTRATO')
        plt.suptitle('')
    
    plt.tight_layout()
    plt.show()

# %%
analizar_demografico(notas)
# Out:
# ================================================================================
# ANÁLISIS DEMOGRÁFICO Y SOCIOECONÓMICO
# ================================================================================
#
# --- Distribución por ESTRATO ---
#           Count  Porcentaje (%)
# ESTRATO
# 1         63289            2.88
# 2        156034            7.11
# 3        408095            18.6
# 4        404738           18.44
# 5        584801           26.65
# 6        577655           26.32
#
# --- Notas por ESTRATO ---
#          mean  median   count  porcentaje
# ESTRATO
# 1        3.79     3.9   63289        2.88
# 2        3.89     4.0  156034        7.11
# 3        3.87     4.0  408095       18.60
# 4        3.84     3.9  404738       18.44
# 5        3.85     3.9  584801       26.65
# 6        3.86     4.0  577655       26.32
#
# --- First Generation ---
#                     Count  Porcentaje (%)
# FIRST_GENERATION
# False             1803174           82.16
# True               391438           17.84
#
# --- Notas por First Generation ---
#                   mean    count  porcentaje
# FIRST_GENERATION
# False             3.85  1803174       82.16
# True              3.89   391438       17.84
#
# --- Discapacidad ---
#                     Count  Porcentaje (%)
# DISCAPACIDAD
# Sin discapacidad  2164256           98.62
# Visión              24750            1.13
# Auditiva             2816            0.13
# Movilidad            1557            0.07
# Médica                512            0.02
# Aprendizaje           469            0.02
# Otra                  252            0.01
#
# --- Notas por Tipo de Discapacidad ---
#                   mean    count  porcentaje
# DISCAPACIDAD
# Aprendizaje       3.62      469        0.02
# Auditiva          3.84     2816        0.13
# Movilidad         3.97     1557        0.07
# Médica            3.85      512        0.02
# Otra              4.31      252        0.01
# Sin discapacidad  3.86  2164256       98.62
# Visión            3.85    24750        1.13
#
# --- Desplazados Víctimas del Conflicto ---
#                                 Count  Porcentaje (%)
# DESPLAZADO_VICTIMA_CONFLICTO
# False                         2187196           99.66
# True                             7416            0.34
#
# --- Notas por Condición de Desplazamiento ---
#                               mean    count  porcentaje
# DESPLAZADO_VICTIMA_CONFLICTO
# False                         3.86  2187196       99.66
# True                          3.99     7416        0.34

# %% [markdown]
# # 8. ANÁLISIS DE DESERCIÓN Y GRADUACIÓN

# %%
def analizar_desercion_graduacion(df):
    """
    Análisis de deserción, graduación y estado activo
    """
    print("\n" + "="*80)
    print("ANÁLISIS DE DESERCIÓN Y GRADUACIÓN")
    print("="*80)
    
    # Análisis por estudiante único
    estudiantes = df.groupby('EMPLID_ANÓNIMO').agg({
        'DESERTOR': 'first',
        'GRADUADO': 'first',
        'ACTIVO': 'first',
        'NOTA': 'mean',
        'SEMESTRE': 'count',
        'COHORTE': 'first'
    }).reset_index()
    estudiantes.columns = ['EMPLID_ANÓNIMO', 'DESERTOR', 'GRADUADO', 'ACTIVO', 'NOTA_PROMEDIO', 'NUM_MATERIAS', 'COHORTE']
    
    print(f"\nNúmero total de estudiantes únicos: {len(estudiantes):,}")
    
    # Distribución de estados
    print("\n--- Distribución de Estados ---")
    print(f"Desertores: {estudiantes['DESERTOR'].sum():,} ({estudiantes['DESERTOR'].sum()/len(estudiantes)*100:.2f}%)")
    print(f"Graduados: {estudiantes['GRADUADO'].sum():,} ({estudiantes['GRADUADO'].sum()/len(estudiantes)*100:.2f}%)")
    print(f"Activos: {estudiantes['ACTIVO'].sum():,} ({estudiantes['ACTIVO'].sum()/len(estudiantes)*100:.2f}%)")
    
    # Comparación de notas
    print("\n--- Nota Promedio por Estado ---")
    print(f"Desertores: {estudiantes[estudiantes['DESERTOR']==1]['NOTA_PROMEDIO'].mean():.2f}")
    print(f"Graduados: {estudiantes[estudiantes['GRADUADO']==1]['NOTA_PROMEDIO'].mean():.2f}")
    print(f"Activos: {estudiantes[estudiantes['ACTIVO']==1]['NOTA_PROMEDIO'].mean():.2f}")
    
    # Visualizaciones - Primera figura
    fig1, axes1 = plt.subplots(2, 2, figsize=(15, 10))
    
    # Distribución de estados
    estados = pd.Series({
        'Desertores': estudiantes['DESERTOR'].sum(),
        'Graduados': estudiantes['GRADUADO'].sum(),
        'Activos': estudiantes['ACTIVO'].sum()
    })
    estados.plot(kind='pie', ax=axes1[0, 0], autopct='%1.1f%%', startangle=90)
    axes1[0, 0].set_title('Distribución de Estudiantes por Estado')
    axes1[0, 0].set_ylabel('')
    
    # Notas promedio por estado CON ETIQUETAS
    notas_estado = pd.Series({
        'Desertores': estudiantes[estudiantes['DESERTOR']==1]['NOTA_PROMEDIO'].mean(),
        'Graduados': estudiantes[estudiantes['GRADUADO']==1]['NOTA_PROMEDIO'].mean(),
        'Activos': estudiantes[estudiantes['ACTIVO']==1]['NOTA_PROMEDIO'].mean()
    })
    bars = notas_estado.plot(kind='bar', ax=axes1[0, 1], color=['red', 'green', 'blue'])
    axes1[0, 1].set_xlabel('Estado')
    axes1[0, 1].set_ylabel('Nota Promedio')
    axes1[0, 1].set_title('Nota Promedio por Estado del Estudiante')
    axes1[0, 1].tick_params(axis='x', rotation=0)
    
    # Agregar etiquetas de datos
    for i, (idx, val) in enumerate(notas_estado.items()):
        axes1[0, 1].text(i, val, f'{val:.2f}', ha='center', va='bottom', fontweight='bold', fontsize=10)
    
    # Distribución de notas por estado
    for estado in ['DESERTOR', 'GRADUADO', 'ACTIVO']:
        data = estudiantes[estudiantes[estado]==1]['NOTA_PROMEDIO'].dropna()
        axes1[1, 0].hist(data, alpha=0.5, label=estado, bins=30)
    axes1[1, 0].set_xlabel('Nota Promedio')
    axes1[1, 0].set_ylabel('Frecuencia')
    axes1[1, 0].set_title('Distribución de Notas Promedio por Estado')
    axes1[1, 0].legend()
    
    # Tasa de deserción por escuela CON ETIQUETAS
    desercion_escuela = df.groupby('ESCUELA')['DESERTOR'].mean() * 100
    desercion_escuela_sorted = desercion_escuela.sort_values(ascending=True)
    bars2 = desercion_escuela_sorted.plot(kind='barh', ax=axes1[1, 1], color='salmon')
    axes1[1, 1].set_xlabel('Tasa de Deserción (%)')
    axes1[1, 1].set_title('Tasa de Deserción por ESCUELA')
    
    # Agregar etiquetas de datos
    for i, (idx, val) in enumerate(desercion_escuela_sorted.items()):
        axes1[1, 1].text(val, i, f'{val:.1f}%', ha='left', va='center', fontweight='bold', fontsize=9)
    
    plt.tight_layout()
    plt.show()
    
    # NUEVA GRÁFICA: Estudiantes por COHORTE y Estado
    print("\n--- Análisis por COHORTE ---")
    
    # Preparar datos por cohorte
    cohorte_desertor = estudiantes[estudiantes['DESERTOR']==1].groupby('COHORTE').size()
    cohorte_graduado = estudiantes[estudiantes['GRADUADO']==1].groupby('COHORTE').size()
    cohorte_activo = estudiantes[estudiantes['ACTIVO']==1].groupby('COHORTE').size()
    
    # Crear dataframe consolidado
    cohortes_todas = sorted(estudiantes['COHORTE'].unique())
    df_cohorte = pd.DataFrame({
        'COHORTE': cohortes_todas,
        'Desertores': [cohorte_desertor.get(c, 0) for c in cohortes_todas],
        'Graduados': [cohorte_graduado.get(c, 0) for c in cohortes_todas],
        'Activos': [cohorte_activo.get(c, 0) for c in cohortes_todas]
    })
    
    # Gráfica apilada por cohorte
    fig2, ax2 = plt.subplots(figsize=(16, 6))
    
    x = np.arange(len(df_cohorte))
    width = 0.8
    
    p1 = ax2.bar(x, df_cohorte['Desertores'], width, label='Desertores', color='#FF6B6B')
    p2 = ax2.bar(x, df_cohorte['Graduados'], width, bottom=df_cohorte['Desertores'], 
                 label='Graduados', color='#9b8cf5')
    p3 = ax2.bar(x, df_cohorte['Activos'], width, 
                 bottom=df_cohorte['Desertores'] + df_cohorte['Graduados'],
                 label='Activos', color='#95E1D3')
    
    ax2.set_xlabel('COHORTE', fontsize=12, fontweight='bold')
    ax2.set_ylabel('Número de Estudiantes', fontsize=12, fontweight='bold')
    ax2.set_title('Distribución de Estudiantes por COHORTE y Estado', fontsize=14, fontweight='bold', pad=15)
    ax2.set_xticks(x)
    ax2.set_xticklabels(df_cohorte['COHORTE'], rotation=45, ha='right')
    ax2.legend(loc='upper left')
    ax2.grid(True, alpha=0.3, axis='y')
    
    plt.tight_layout()
    plt.show()
    
    # Tabla resumen por cohorte
    print("\n--- Tabla: Estudiantes por COHORTE y Estado ---")
    df_cohorte['Total'] = df_cohorte['Desertores'] + df_cohorte['Graduados'] + df_cohorte['Activos']
    df_cohorte['% Deserción'] = (df_cohorte['Desertores'] / df_cohorte['Total'] * 100).round(2)
    df_cohorte['% Graduación'] = (df_cohorte['Graduados'] / df_cohorte['Total'] * 100).round(2)
    print(df_cohorte.to_string(index=False))
       
    plt.tight_layout()
    plt.show()

# %%
analizar_desercion_graduacion(notas)
# Out:
# ================================================================================
# ANÁLISIS DE DESERCIÓN Y GRADUACIÓN
# ================================================================================
#
# Número total de estudiantes únicos: 58,406
#
# --- Distribución de Estados ---
# Desertores: 19,255 (32.97%)
# Graduados: 30,117 (51.56%)
# Activos: 8,745 (14.97%)
#
# --- Nota Promedio por Estado ---
# Desertores: 3.15
# Graduados: 3.98
# Activos: 4.03
# --- Análisis por COHORTE ---
# --- Tabla: Estudiantes por COHORTE y Estado ---
# COHORTE  Desertores  Graduados  Activos  Total  % Deserción  % Graduación
#  1979-1           0          2        0      2         0.00        100.00
#  1980-1           1          0        0      1       100.00          0.00
#  1981-1           0          1        0      1         0.00        100.00
#  1982-1           0          1        0      1         0.00        100.00
#  1983-1           0          2        0      2         0.00        100.00
#  1984-1           1          0        0      1       100.00          0.00
#  1984-3           1          0        0      1       100.00          0.00
#  1985-1           0          1        0      1         0.00        100.00
#  1985-3           0          1        0      1         0.00        100.00
#  1986-1           0          4        0      4         0.00        100.00
#  1987-1           2          3        0      5        40.00         60.00
#  1987-3           0          1        0      1         0.00        100.00
#  1988-1           2          3        0      5        40.00         60.00
#  1988-3           2          1        0      3        66.67         33.33
#  1989-1           2          1        0      3        66.67         33.33
#  1989-3           1          5        0      6        16.67         83.33
#  1990-1           4          4        0      8        50.00         50.00
#  1990-3           0          4        0      4         0.00        100.00
#  1991-1           2         13        0     15        13.33         86.67
#  1991-3           5          6        0     11        45.45         54.55
#  1992-1           3         16        0     19        15.79         84.21
#  1992-3           2         17        0     19        10.53         89.47
#  1993-1          10         66        0     76        13.16         86.84
#  1993-3           1         53        0     54         1.85         98.15
#  1994-1          18        247        0    265         6.79         93.21
#  1994-2          14        153        0    167         8.38         91.62
#  1995-1          40        524        0    564         7.09         92.91
#  1995-2          23        210        0    233         9.87         90.13
#  1996-1          63        535        0    598        10.54         89.46
#  1996-2          33        216        1    250        13.20         86.40
#  1997-1         117        600        0    717        16.32         83.68
#  1997-2          61        196        0    257        23.74         76.26
#  1998-1         179        688        0    867        20.65         79.35
#  1998-2          75        223        0    298        25.17         74.83
#  1999-1         295        658        0    953        30.95         69.05
#  1999-2         171        273        0    444        38.51         61.49
#  2000-1         497        657        2   1156        42.99         56.83
#  2000-2         247        292        1    540        45.74         54.07
#  2001-1         575        699        0   1274        45.13         54.87
#  2001-2         238        253        0    491        48.47         51.53
#  2002-1         497        719        0   1216        40.87         59.13
#  2002-2         262        292        1    555        47.21         52.61
#  2003-1         512        715        0   1227        41.73         58.27
#  2003-2         243        240        1    484        50.21         49.59
#  2004-1         451        666        1   1118        40.34         59.57
#  2004-2         217        242        0    459        47.28         52.72
#  2005-1         346        665        0   1011        34.22         65.78
#  2005-2         281        354        0    635        44.25         55.75
#  2006-1         440        737        1   1178        37.35         62.56
#  2006-2         205        279        0    484        42.36         57.64
#  2007-1         426        773        2   1201        35.47         64.36
#  2007-2         212        240        1    453        46.80         52.98
#  2008-1         415        889        1   1305        31.80         68.12
#  2008-2         251        323        0    574        43.73         56.27
#  2009-1         411        797        5   1213        33.88         65.70
#  2009-2         248        343        1    592        41.89         57.94
#  2010-1         390        870        2   1262        30.90         68.94
#  2010-2         266        385        3    654        40.67         58.87
#  2011-1         434        912        3   1349        32.17         67.61
#  2011-2         293        431        0    724        40.47         59.53
#  2012-1         447        944        3   1394        32.07         67.72
#  2012-2         274        467        3    744        36.83         62.77
#  2013-1         476        893        5   1374        34.64         64.99
#  2013-2         269        472        2    743        36.20         63.53
#  2014-1         477       1007        9   1493        31.95         67.45
#  2014-2         363        478        9    850        42.71         56.24
#  2015-1         587       1080       15   1682        34.90         64.21
#  2015-2         387        484       12    883        43.83         54.81
#  2016-1         633       1223       15   1871        33.83         65.37
#  2016-2         417        477       18    912        45.72         52.30
#  2017-1         625       1023       50   1698        36.81         60.25
#  2017-2         430        502       30    962        44.70         52.18
#  2018-1         492        942       55   1489        33.04         63.26
#  2018-2         455        432       48    935        48.66         46.20
#  2019-1         479        735      119   1333        35.93         55.14
#  2019-2         382        411      102    895        42.68         45.92
#  2020-1         448        599      282   1329        33.71         45.07
#  2020-2         203        240      194    637        31.87         37.68
#  2021-1         379        169      720   1268        29.89         13.33
#  2021-2         178         20      512    710        25.07          2.82
#  2022-1         317         14      959   1290        24.57          1.09
#  2022-2         196          2      653    851        23.03          0.24
#  2023-1         270          2      955   1227        22.00          0.16
#  2023-2         172          0      774    946        18.18          0.00
#  2024-1         192          0     1090   1282        14.98          0.00
#  2024-2         151          0      886   1037        14.56          0.00
#  2025-1          71          0     1199   1270         5.59          0.00

# %% [markdown]
# # 9. ANÁLISIS DE CRÉDITOS

# %%
def analizar_creditos(df):
    """
    Análisis completo de créditos académicos y su relación con notas
    """
    print("\n" + "="*80)
    print("ANÁLISIS DE CRÉDITOS")
    print("="*80)
    
    print("\n--- Estadísticas Generales de Créditos ---")
    print(df['CRÉDITOS'].describe())
    
    print(f"\nTotal de créditos registrados: {df['CRÉDITOS'].sum():,.0f}")
    print(f"Promedio de créditos por materia: {df['CRÉDITOS'].mean():.2f}")
    
    # Distribución de créditos
    print("\n--- Distribución de Créditos por Materia ---")
    dist_creditos = df['CRÉDITOS'].value_counts().sort_index()
    for credito, count in dist_creditos.items():
        print(f"  {credito} créditos: {count:,} materias ({count/len(df)*100:.1f}%)")
    
    # Créditos por estudiante
    print("\n--- Análisis de Créditos por Estudiante ---")
    creditos_estudiante = df.groupby('EMPLID_ANÓNIMO')['CRÉDITOS'].sum()
    print(f"Promedio de créditos por estudiante: {creditos_estudiante.mean():.1f}")
    print(f"Mediana de créditos por estudiante: {creditos_estudiante.median():.1f}")
    print(f"Máximo de créditos por estudiante: {creditos_estudiante.max():.0f}")
    print(f"Mínimo de créditos por estudiante: {creditos_estudiante.min():.0f}")
    
    # Relación créditos y nota
    print("\n--- Relación entre Créditos y Notas ---")
    creditos_nota = df.groupby('CRÉDITOS').agg({
        'NOTA': ['mean', 'median', 'std', 'count']
    }).round(2)
    creditos_nota.columns = ['Nota_Promedio', 'Nota_Mediana', 'Desv_Std', 'Cantidad']
    print(creditos_nota)
    
    # Análisis de aprobación por créditos (considerando sistema de calificación)
    df['APROBADO'] = np.where(
        (df['SISTEMA_CALIFICACION'] == 'C30') & (df['NOTA'] >= 3.0), 1,
        np.where((df['SISTEMA_CALIFICACION'] == 'C35') & (df['NOTA'] >= 3.5), 1, 0)
    )
    tasa_aprobacion_creditos = df.groupby('CRÉDITOS')['APROBADO'].mean() * 100
    
    print("\n--- Tasa de Aprobación por Créditos (según sistema de calificación) ---")
    for credito in sorted(df['CRÉDITOS'].unique()):
        tasa = tasa_aprobacion_creditos[credito]
        count = (df['CRÉDITOS'] == credito).sum()
        # Mostrar distribución de sistemas de calificación por crédito
        sistemas = df[df['CRÉDITOS'] == credito]['SISTEMA_CALIFICACION'].value_counts()
        print(f"  {credito} créditos: {tasa:.1f}% ({count:,} registros)")
        for sistema, cant in sistemas.items():
            print(f"    → {sistema}: {cant:,} materias")
    
    # Análisis por estado del estudiante
    print("\n--- Créditos Promedio por Estado del Estudiante ---")
    creditos_por_estado = df.groupby('EMPLID_ANÓNIMO').agg({
        'CRÉDITOS': 'sum',
        'DESERTOR': 'first',
        'GRADUADO': 'first',
        'ACTIVO': 'first'
    })
    
    creditos_desertores = creditos_por_estado[creditos_por_estado['DESERTOR']==1]['CRÉDITOS'].mean()
    creditos_graduados = creditos_por_estado[creditos_por_estado['GRADUADO']==1]['CRÉDITOS'].mean()
    creditos_activos = creditos_por_estado[creditos_por_estado['ACTIVO']==1]['CRÉDITOS'].mean()
    
    print(f"  Desertores: {creditos_desertores:.1f} créditos")
    print(f"  Graduados: {creditos_graduados:.1f} créditos")
    print(f"  Activos: {creditos_activos:.1f} créditos")
    
    # Visualizaciones mejoradas con etiquetas
    fig, axes = plt.subplots(2, 3, figsize=(22, 14))
    
    # 1. Distribución de créditos por materia CON ETIQUETAS
    dist_creditos_sorted = dist_creditos.sort_index()
    bars1 = axes[0, 0].bar(dist_creditos_sorted.index, dist_creditos_sorted.values, 
                           color='steelblue', edgecolor='black', alpha=0.7)
    axes[0, 0].set_xlabel('Número de Créditos', fontsize=13, fontweight='bold')
    axes[0, 0].set_ylabel('Frecuencia', fontsize=13, fontweight='bold')
    axes[0, 0].set_title('Distribución de Créditos por Materia', fontsize=14, fontweight='bold', pad=15)
    axes[0, 0].grid(True, alpha=0.3, axis='y')
    axes[0, 0].tick_params(axis='both', labelsize=11)
    
    # Agregar etiquetas
    for bar in bars1:
        height = bar.get_height()
        axes[0, 0].text(bar.get_x() + bar.get_width()/2., height,
                       f'{int(height):,}',
                       ha='center', va='bottom', fontweight='bold', fontsize=10)
    
    # 2. Nota promedio por créditos CON ETIQUETAS
    nota_prom_creditos = df.groupby('CRÉDITOS')['NOTA'].mean().sort_index()
    bars2 = axes[0, 1].plot(nota_prom_creditos.index, nota_prom_creditos.values, 
                            marker='o', linewidth=3, markersize=10, color='#e74c3c')
    axes[0, 1].set_xlabel('Número de Créditos', fontsize=13, fontweight='bold')
    axes[0, 1].set_ylabel('Nota Promedio', fontsize=13, fontweight='bold')
    axes[0, 1].set_title('Nota Promedio según Número de Créditos', fontsize=14, fontweight='bold', pad=15)
    axes[0, 1].grid(True, alpha=0.3)
    axes[0, 1].set_ylim([0, 5])
    axes[0, 1].tick_params(axis='both', labelsize=11)
    
    # Agregar etiquetas
    for x, y in zip(nota_prom_creditos.index, nota_prom_creditos.values):
        axes[0, 1].annotate(f'{y:.2f}', (x, y), textcoords="offset points", 
                           xytext=(0,10), ha='center', fontweight='bold', fontsize=10)
    
    # 3. Tasa de aprobación por créditos CON ETIQUETAS
    tasa_aprobacion_sorted = tasa_aprobacion_creditos.sort_index()
    bars3 = axes[0, 2].bar(tasa_aprobacion_sorted.index, tasa_aprobacion_sorted.values,
                           color='#27ae60', edgecolor='black', alpha=0.7)
    axes[0, 2].set_xlabel('Número de Créditos', fontsize=13, fontweight='bold')
    axes[0, 2].set_ylabel('Tasa de Aprobación (%)', fontsize=13, fontweight='bold')
    axes[0, 2].set_title('Tasa de Aprobación por Número de Créditos', fontsize=14, fontweight='bold', pad=15)
    axes[0, 2].grid(True, alpha=0.3, axis='y')
    axes[0, 2].set_ylim([0, 100])
    axes[0, 2].tick_params(axis='both', labelsize=11)
    
    # Agregar etiquetas
    for bar in bars3:
        height = bar.get_height()
        axes[0, 2].text(bar.get_x() + bar.get_width()/2., height,
                       f'{height:.1f}%',
                       ha='center', va='bottom', fontweight='bold', fontsize=10)
    
    # 4. Boxplot de notas por créditos
    creditos_orden = sorted(df['CRÉDITOS'].unique())
    data_boxplot = [df[df['CRÉDITOS'] == c]['NOTA'].dropna() for c in creditos_orden]
    bp = axes[1, 0].boxplot(data_boxplot, labels=creditos_orden, patch_artist=True)
    
    # Colorear boxplots
    for patch in bp['boxes']:
        patch.set_facecolor('#3498db')
        patch.set_alpha(0.7)
    
    axes[1, 0].set_xlabel('Número de Créditos', fontsize=13, fontweight='bold')
    axes[1, 0].set_ylabel('Nota', fontsize=13, fontweight='bold')
    axes[1, 0].set_title('Distribución de Notas por Créditos', fontsize=14, fontweight='bold', pad=15)
    axes[1, 0].grid(True, alpha=0.3, axis='y')
    axes[1, 0].axhline(y=3.0, color='r', linestyle='--', linewidth=2, label='Aprobación mínima')
    axes[1, 0].legend(fontsize=10)
    axes[1, 0].tick_params(axis='both', labelsize=11)
    
    # 5. Créditos acumulados por estado CON ETIQUETAS
    estados = ['Desertores', 'Graduados', 'Activos']
    creditos_estados = [creditos_desertores, creditos_graduados, creditos_activos]
    colores = ['#e74c3c', '#27ae60', '#3498db']
    
    bars5 = axes[1, 1].bar(estados, creditos_estados, color=colores, 
                           edgecolor='black', alpha=0.7)
    axes[1, 1].set_ylabel('Créditos Promedio Acumulados', fontsize=13, fontweight='bold')
    axes[1, 1].set_title('Créditos Promedio por Estado del Estudiante', fontsize=14, fontweight='bold', pad=15)
    axes[1, 1].grid(True, alpha=0.3, axis='y')
    axes[1, 1].tick_params(axis='both', labelsize=11)
    
    # Agregar etiquetas
    for bar, val in zip(bars5, creditos_estados):
        height = bar.get_height()
        axes[1, 1].text(bar.get_x() + bar.get_width()/2., height,
                       f'{val:.1f}',
                       ha='center', va='bottom', fontweight='bold', fontsize=11)
    
    # 6. Scatter plot: Créditos acumulados vs Nota promedio
    # Calcular por estudiante
    estudiantes_metricas = df.groupby('EMPLID_ANÓNIMO').agg({
        'CRÉDITOS': 'sum',
        'NOTA': 'mean',
        'DESERTOR': 'first'
    })
    
    # Separar por estado
    desertores = estudiantes_metricas[estudiantes_metricas['DESERTOR'] == 1]
    exitosos = estudiantes_metricas[estudiantes_metricas['DESERTOR'] == 0]
    
    axes[1, 2].scatter(exitosos['CRÉDITOS'], exitosos['NOTA'], 
                      alpha=0.5, s=40, c='#27ae60', label='Exitosos', edgecolors='none')
    axes[1, 2].scatter(desertores['CRÉDITOS'], desertores['NOTA'], 
                      alpha=0.6, s=40, c='#e74c3c', label='Desertores', edgecolors='none')
    axes[1, 2].axhline(y=3.0, color='gray', linestyle='--', linewidth=1, alpha=0.5)
    axes[1, 2].set_xlabel('Créditos Acumulados', fontsize=13, fontweight='bold')
    axes[1, 2].set_ylabel('Nota Promedio', fontsize=13, fontweight='bold')
    axes[1, 2].set_title('Créditos Acumulados vs Nota Promedio', fontsize=14, fontweight='bold', pad=15)
    axes[1, 2].legend(loc='best', fontsize=11)
    axes[1, 2].grid(True, alpha=0.3)
    axes[1, 2].tick_params(axis='both', labelsize=11)
    
    plt.tight_layout()
    plt.show()
    
    # Tabla resumen
    print("\n" + "-"*80)
    print("TABLA RESUMEN: CRÉDITOS Y RENDIMIENTO")
    print("-"*80)
    
    resumen_creditos = df.groupby('CRÉDITOS').agg({
        'NOTA': ['mean', 'count'],
        'APROBADO': 'mean'
    }).round(2)
    resumen_creditos.columns = ['Nota_Promedio', 'Cantidad_Registros', 'Tasa_Aprobacion']
    resumen_creditos['Tasa_Aprobacion'] = (resumen_creditos['Tasa_Aprobacion'] * 100).round(1)
    resumen_creditos['Porcentaje_Total'] = (resumen_creditos['Cantidad_Registros'] / len(df) * 100).round(1)
    
    print(resumen_creditos.to_string())

# %%
analizar_creditos(notas)
# Out:
# ================================================================================
# ANÁLISIS DE CRÉDITOS
# ================================================================================
#
# --- Estadísticas Generales de Créditos ---
# count    2.194612e+06
# mean     3.326536e+00
# std      2.139776e+00
# min      1.000000e+00
# 25%      3.000000e+00
# 50%      3.000000e+00
# 75%      3.000000e+00
# max      2.400000e+01
# Name: CRÉDITOS, dtype: float64
#
# Total de créditos registrados: 7,300,455
# Promedio de créditos por materia: 3.33
#
# --- Distribución de Créditos por Materia ---
#   1 créditos: 113,345 materias (5.2%)
#   2 créditos: 188,247 materias (8.6%)
#   3 créditos: 1,389,476 materias (63.3%)
#   4 créditos: 415,512 materias (18.9%)
#   5 créditos: 4,715 materias (0.2%)
#   6 créditos: 42,459 materias (1.9%)
#   7 créditos: 22 materias (0.0%)
#   8 créditos: 4,815 materias (0.2%)
#   9 créditos: 104 materias (0.0%)
#   10 créditos: 1,408 materias (0.1%)
#   11 créditos: 1 materias (0.0%)
#   12 créditos: 71 materias (0.0%)
#   16 créditos: 5 materias (0.0%)
#   18 créditos: 20,733 materias (0.9%)
#   20 créditos: 13,698 materias (0.6%)
#   24 créditos: 1 materias (0.0%)
#
# --- Análisis de Créditos por Estudiante ---
# Promedio de créditos por estudiante: 125.0
# Mediana de créditos por estudiante: 148.0
# Máximo de créditos por estudiante: 569
# Mínimo de créditos por estudiante: 1
#
# --- Relación entre Créditos y Notas ---
#           Nota_Promedio  Nota_Mediana  Desv_Std  Cantidad
# CRÉDITOS
# 1                  4.35           4.6      0.88    113345
# 2                  4.05           4.2      0.76    188247
# 3                  3.82           3.9      0.82   1389476
# 4                  3.68           3.7      0.73    415512
# 5                  4.32           4.5      0.67      4715
# 6                  3.79           3.9      0.82     42459
# 7                  4.10           4.3      0.52        22
# 8                  4.00           4.2      0.95      4815
# 9                  4.11           4.3      0.81       104
# 10                 3.67           3.7      0.57      1408
# 11                 5.00           5.0       NaN         1
# 12                 3.67           4.4      1.70        71
# 16                 0.00           0.0      0.00         5
# 18                 4.71           4.8      0.31     20733
# 20                 4.68           4.8      0.37     13698
# 24                 0.00           0.0       NaN         1
#
# --- Tasa de Aprobación por Créditos (según sistema de calificación) ---
#   1 créditos: 95.6% (113,345 registros)
#     → C30: 113,340 materias
#     → C35: 5 materias
#   2 créditos: 95.4% (188,247 registros)
#     → C30: 188,211 materias
#     → C35: 36 materias
#   3 créditos: 92.1% (1,389,476 registros)
#     → C30: 1,389,435 materias
#     → C35: 41 materias
#   4 créditos: 91.5% (415,512 registros)
#     → C30: 415,512 materias
#   5 créditos: 97.8% (4,715 registros)
#     → C30: 4,714 materias
#     → C35: 1 materias
#   6 créditos: 91.1% (42,459 registros)
#     → C30: 42,459 materias
#   7 créditos: 100.0% (22 registros)
#     → C30: 22 materias
#   8 créditos: 93.7% (4,815 registros)
#     → C30: 4,815 materias
#   9 créditos: 94.2% (104 registros)
#     → C30: 104 materias
#   10 créditos: 93.2% (1,408 registros)
#     → C30: 1,408 materias
#   11 créditos: 100.0% (1 registros)
#     → C30: 1 materias
#   12 créditos: 83.1% (71 registros)
#     → C30: 71 materias
#   16 créditos: 0.0% (5 registros)
#     → C30: 5 materias
#   18 créditos: 99.9% (20,733 registros)
#     → C30: 20,733 materias
#   20 créditos: 99.5% (13,698 registros)
#     → C30: 13,698 materias
#   24 créditos: 0.0% (1 registros)
#     → C30: 1 materias
#
# --- Créditos Promedio por Estado del Estudiante ---
#   Desertores: 55.4 créditos
#   Graduados: 181.9 créditos
#   Activos: 86.3 créditos
# --------------------------------------------------------------------------------
# TABLA RESUMEN: CRÉDITOS Y RENDIMIENTO
# --------------------------------------------------------------------------------
#           Nota_Promedio  Cantidad_Registros  Tasa_Aprobacion  Porcentaje_Total
# CRÉDITOS
# 1                  4.35              113345             96.0               5.2
# 2                  4.05              188247             95.0               8.6
# 3                  3.82             1389476             92.0              63.3
# 4                  3.68              415512             91.0              18.9
# 5                  4.32                4715             98.0               0.2
# 6                  3.79               42459             91.0               1.9
# 7                  4.10                  22            100.0               0.0
# 8                  4.00                4815             94.0               0.2
# 9                  4.11                 104             94.0               0.0
# 10                 3.67                1408             93.0               0.1
# 11                 5.00                   1            100.0               0.0
# 12                 3.67                  71             83.0               0.0
# 16                 0.00                   5              0.0               0.0
# 18                 4.71               20733            100.0               0.9
# 20                 4.68               13698             99.0               0.6
# 24                 0.00                   1              0.0               0.0

# %% [markdown]
# # 10. CORRELACIONES Y RELACIONES

# %%
def analizar_correlaciones(df):
    """
    Análisis de correlaciones entre variables numéricas y categóricas
    """
    print("\n" + "="*80)
    print("ANÁLISIS DE CORRELACIONES Y RELACIONES")
    print("="*80)
    
    # ========================================================================
    # 1. CORRELACIÓN ENTRE VARIABLES NUMÉRICAS
    # ========================================================================
    print("\n" + "-"*80)
    print("1. CORRELACIÓN ENTRE VARIABLES NUMÉRICAS")
    print("-"*80)
    
    # Seleccionar variables numéricas relevantes
    num_cols = ['NOTA', 'CRÉDITOS']
    
    # Agregar variables derivadas por estudiante
    estudiantes_metricas = df.groupby('EMPLID_ANÓNIMO').agg({
        'NOTA': 'mean',
        'CRÉDITOS': 'sum',
        'SEMESTRE': 'count',
        'DESERTOR': 'first',
        'GRADUADO': 'first',
        'ACTIVO': 'first'
    }).reset_index()
    estudiantes_metricas.columns = ['EMPLID_ANÓNIMO', 'NOTA_PROMEDIO', 'CREDITOS_TOTALES', 
                                     'NUM_MATERIAS', 'DESERTOR', 'GRADUADO', 'ACTIVO']
    
    # Matriz de correlación de variables numéricas
    corr_vars = ['NOTA_PROMEDIO', 'CREDITOS_TOTALES', 'NUM_MATERIAS', 'DESERTOR', 'GRADUADO', 'ACTIVO']
    corr_matrix = estudiantes_metricas[corr_vars].corr()
    
    print("\n--- Matriz de Correlación ---")
    print(corr_matrix.round(3))
    
    # Visualización
    fig1, ax1 = plt.subplots(figsize=(10, 8))
    sns.heatmap(corr_matrix, annot=True, fmt='.3f', cmap='coolwarm', 
                center=0, square=True, linewidths=1, cbar_kws={"shrink": 0.8})
    ax1.set_title('Matriz de Correlación - Variables Numéricas', fontsize=14, fontweight='bold', pad=15)
    plt.tight_layout()
    plt.show()
    
    # Identificar correlaciones más fuertes
    print("\n--- Correlaciones más fuertes (|r| > 0.3) ---")
    correlaciones_fuertes = []
    for i in range(len(corr_matrix.columns)):
        for j in range(i+1, len(corr_matrix.columns)):
            corr_val = corr_matrix.iloc[i, j]
            if abs(corr_val) > 0.3:
                correlaciones_fuertes.append({
                    'Variable 1': corr_matrix.columns[i],
                    'Variable 2': corr_matrix.columns[j],
                    'Correlación': corr_val
                })
    
    if correlaciones_fuertes:
        df_corr_fuertes = pd.DataFrame(correlaciones_fuertes).sort_values('Correlación', 
                                                                           key=abs, ascending=False)
        print(df_corr_fuertes.to_string(index=False))
    else:
        print("No se encontraron correlaciones fuertes (|r| > 0.3)")
    
    # ========================================================================
    # 2. RELACIÓN ENTRE VARIABLES CATEGÓRICAS Y NOTA
    # ========================================================================
    print("\n" + "-"*80)
    print("2. RELACIÓN ENTRE VARIABLES CATEGÓRICAS Y NOTA")
    print("-"*80)
    
    # Variables categóricas a analizar
    cat_vars = []
    if 'ESTRATO' in df.columns:
        cat_vars.append('ESTRATO')
    if 'FIRST_GENERATION' in df.columns:
        cat_vars.append('FIRST_GENERATION')
    if 'ESCUELA' in df.columns:
        cat_vars.append('ESCUELA')
    if 'DESPLAZADO_VICTIMA_CONFLICTO' in df.columns:
        cat_vars.append('DESPLAZADO_VICTIMA_CONFLICTO')
    
    # Análisis de varianza (ANOVA) - F-statistic
    print("\n--- Análisis de Varianza (ANOVA) ---")
    print("Mide si las diferencias de NOTA entre categorías son estadísticamente significativas")
    print("F-statistic alto = Mayor diferencia entre grupos\n")
    
    from scipy import stats
    
    anova_results = []
    for var in cat_vars:
        grupos = [group['NOTA'].dropna() for name, group in df.groupby(var)]
        if len(grupos) > 1:
            f_stat, p_value = stats.f_oneway(*grupos)
            anova_results.append({
                'Variable': var,
                'F-statistic': f_stat,
                'p-value': p_value,
                'Significativo': 'Sí' if p_value < 0.05 else 'No'
            })
    
    if anova_results:
        df_anova = pd.DataFrame(anova_results).sort_values('F-statistic', ascending=False)
        print(df_anova.to_string(index=False))
    
    # ========================================================================
    # 3. BOXPLOTS COMPARATIVOS
    # ========================================================================
    print("\n" + "-"*80)
    print("3. VISUALIZACIÓN DE RELACIONES CATEGÓRICAS")
    print("-"*80)
    
    # Crear subplots para las variables más relevantes
    n_plots = min(4, len(cat_vars))
    if n_plots > 0:
        fig2, axes2 = plt.subplots(2, 2, figsize=(16, 12))
        axes2 = axes2.flatten()
        
        for idx, var in enumerate(cat_vars[:4]):
            df.boxplot(column='NOTA', by=var, ax=axes2[idx])
            axes2[idx].set_xlabel(var, fontsize=11, fontweight='bold')
            axes2[idx].set_ylabel('NOTA', fontsize=11, fontweight='bold')
            axes2[idx].set_title(f'Distribución de NOTA por {var}', fontsize=12, fontweight='bold')
            axes2[idx].tick_params(axis='x', rotation=45)
        
        # Ocultar subplots vacíos
        for idx in range(n_plots, 4):
            axes2[idx].set_visible(False)
        
        plt.suptitle('')
        plt.tight_layout()
        plt.show()
    
    # ========================================================================
    # 4. ANÁLISIS DE CONTINGENCIA - VARIABLES CATEGÓRICAS vs ESTADO
    # ========================================================================
    print("\n" + "-"*80)
    print("4. RELACIÓN ENTRE VARIABLES DEMOGRÁFICAS Y ESTADO DEL ESTUDIANTE")
    print("-"*80)
    
    # Unir métricas de estudiantes con variables categóricas
    estudiantes_full = df.groupby('EMPLID_ANÓNIMO').agg({
        'DESERTOR': 'first',
        'GRADUADO': 'first',
        'ACTIVO': 'first',
        'ESTRATO': 'first' if 'ESTRATO' in df.columns else 'count',
        'FIRST_GENERATION': 'first' if 'FIRST_GENERATION' in df.columns else 'count',
        'DISCAPACIDAD': 'first' if 'DISCAPACIDAD' in df.columns else 'count',
        'DESPLAZADO_VICTIMA_CONFLICTO': 'first' if 'DESPLAZADO_VICTIMA_CONFLICTO' in df.columns else 'count'
    }).reset_index()
    
    # Crear variable de estado
    estudiantes_full['ESTADO'] = estudiantes_full.apply(
        lambda x: 'Desertor' if x['DESERTOR'] == 1 else ('Graduado' if x['GRADUADO'] == 1 else 'Activo'), 
        axis=1
    )
    
    # Análisis por ESTRATO
    if 'ESTRATO' in df.columns:
        print("\n--- Tasa de Deserción por ESTRATO ---")
        desercion_estrato = estudiantes_full.groupby('ESTRATO')['DESERTOR'].agg(['sum', 'count'])
        desercion_estrato['Tasa_Desercion_%'] = (desercion_estrato['sum'] / desercion_estrato['count'] * 100).round(2)
        desercion_estrato.columns = ['Desertores', 'Total_Estudiantes', 'Tasa_Desercion_%']
        print(desercion_estrato.sort_values('Tasa_Desercion_%', ascending=False))
    
    # Análisis por FIRST_GENERATION
    if 'FIRST_GENERATION' in df.columns:
        print("\n--- Tasa de Deserción por FIRST_GENERATION ---")
        desercion_fg = estudiantes_full.groupby('FIRST_GENERATION')['DESERTOR'].agg(['sum', 'count'])
        desercion_fg['Tasa_Desercion_%'] = (desercion_fg['sum'] / desercion_fg['count'] * 100).round(2)
        desercion_fg.columns = ['Desertores', 'Total_Estudiantes', 'Tasa_Desercion_%']
        print(desercion_fg)
    
    # Análisis por DISCAPACIDAD
    if 'DISCAPACIDAD' in df.columns and estudiantes_full['DISCAPACIDAD'].notna().sum() > 0:
        print("\n--- Tasa de Deserción por DISCAPACIDAD ---")
        desercion_disc = estudiantes_full[estudiantes_full['DISCAPACIDAD'].notna()].groupby('DISCAPACIDAD')['DESERTOR'].agg(['sum', 'count'])
        desercion_disc['Tasa_Desercion_%'] = (desercion_disc['sum'] / desercion_disc['count'] * 100).round(2)
        desercion_disc.columns = ['Desertores', 'Total_Estudiantes', 'Tasa_Desercion_%']
        print(desercion_disc.sort_values('Tasa_Desercion_%', ascending=False))
    
    # ========================================================================
    # 5. VISUALIZACIÓN DE TASAS DE DESERCIÓN POR CATEGORÍAS
    # ========================================================================
    print("\n" + "-"*80)
    print("5. VISUALIZACIÓN DE TASAS DE DESERCIÓN")
    print("-"*80)
    
    # Determinar número de gráficas a mostrar
    n_graficas = 2  # ESTRATO y FIRST_GENERATION siempre
    if 'DISCAPACIDAD' in df.columns and estudiantes_full['DISCAPACIDAD'].notna().sum() > 0:
        n_graficas += 1
    if 'DESPLAZADO_VICTIMA_CONFLICTO' in df.columns:
        n_graficas += 1
    
    # Crear figura con el número apropiado de subplots
    if n_graficas == 2:
        fig3, axes3 = plt.subplots(1, 2, figsize=(16, 6))
        axes3 = [axes3[0], axes3[1]]
    elif n_graficas == 3:
        fig3, axes3 = plt.subplots(1, 3, figsize=(18, 6))
        axes3 = [axes3[0], axes3[1], axes3[2]]
    else:  # 4 gráficas
        fig3, axes3 = plt.subplots(2, 2, figsize=(16, 12))
        axes3 = [axes3[0, 0], axes3[0, 1], axes3[1, 0], axes3[1, 1]]
    
    idx_grafica = 0
    
    # Tasa de deserción por ESTRATO
    if 'ESTRATO' in df.columns:
        desercion_estrato['Tasa_Desercion_%'].plot(kind='bar', ax=axes3[idx_grafica], color='coral')
        axes3[idx_grafica].set_xlabel('ESTRATO', fontsize=12, fontweight='bold')
        axes3[idx_grafica].set_ylabel('Tasa de Deserción (%)', fontsize=12, fontweight='bold')
        axes3[idx_grafica].set_title('Tasa de Deserción por ESTRATO', fontsize=13, fontweight='bold')
        axes3[idx_grafica].tick_params(axis='x', rotation=0)
        axes3[idx_grafica].grid(True, alpha=0.3, axis='y')
        
        # Agregar etiquetas
        for i, val in enumerate(desercion_estrato['Tasa_Desercion_%']):
            axes3[idx_grafica].text(i, val, f'{val:.1f}%', ha='center', va='bottom', fontweight='bold')
        idx_grafica += 1
    
    # Tasa de deserción por FIRST_GENERATION
    if 'FIRST_GENERATION' in df.columns:
        desercion_fg['Tasa_Desercion_%'].plot(kind='bar', ax=axes3[idx_grafica], color='steelblue')
        axes3[idx_grafica].set_xlabel('FIRST_GENERATION', fontsize=12, fontweight='bold')
        axes3[idx_grafica].set_ylabel('Tasa de Deserción (%)', fontsize=12, fontweight='bold')
        axes3[idx_grafica].set_title('Tasa de Deserción por First Generation', fontsize=13, fontweight='bold')
        axes3[idx_grafica].tick_params(axis='x', rotation=0)
        axes3[idx_grafica].grid(True, alpha=0.3, axis='y')
        
        # Agregar etiquetas
        for i, val in enumerate(desercion_fg['Tasa_Desercion_%']):
            axes3[idx_grafica].text(i, val, f'{val:.1f}%', ha='center', va='bottom', fontweight='bold')
        idx_grafica += 1
    
    # Tasa de deserción por DISCAPACIDAD
    if 'DISCAPACIDAD' in df.columns and estudiantes_full['DISCAPACIDAD'].notna().sum() > 0:
        desercion_disc_sorted = desercion_disc.sort_values('Tasa_Desercion_%', ascending=False)
        desercion_disc_sorted['Tasa_Desercion_%'].plot(kind='barh', ax=axes3[idx_grafica], color='mediumpurple')
        axes3[idx_grafica].set_xlabel('Tasa de Deserción (%)', fontsize=12, fontweight='bold')
        axes3[idx_grafica].set_ylabel('DISCAPACIDAD', fontsize=12, fontweight='bold')
        axes3[idx_grafica].set_title('Tasa de Deserción por DISCAPACIDAD', fontsize=13, fontweight='bold')
        axes3[idx_grafica].grid(True, alpha=0.3, axis='x')
        
        # Agregar etiquetas
        for i, val in enumerate(desercion_disc_sorted['Tasa_Desercion_%']):
            axes3[idx_grafica].text(val, i, f'{val:.1f}%', ha='left', va='center', fontweight='bold')
        idx_grafica += 1
    
    # Tasa de deserción por DESPLAZADO_VICTIMA_CONFLICTO
    if 'DESPLAZADO_VICTIMA_CONFLICTO' in df.columns:
        desercion_desplazados = estudiantes_full.groupby('DESPLAZADO_VICTIMA_CONFLICTO')['DESERTOR'].agg(['sum', 'count'])
        desercion_desplazados['Tasa_Desercion_%'] = (desercion_desplazados['sum'] / desercion_desplazados['count'] * 100).round(2)
        desercion_desplazados.columns = ['Desertores', 'Total_Estudiantes', 'Tasa_Desercion_%']
        
        desercion_desplazados['Tasa_Desercion_%'].plot(kind='bar', ax=axes3[idx_grafica], color='darkorange')
        axes3[idx_grafica].set_xlabel('DESPLAZADO_VICTIMA_CONFLICTO', fontsize=12, fontweight='bold')
        axes3[idx_grafica].set_ylabel('Tasa de Deserción (%)', fontsize=12, fontweight='bold')
        axes3[idx_grafica].set_title('Tasa de Deserción por Desplazamiento', fontsize=13, fontweight='bold')
        axes3[idx_grafica].tick_params(axis='x', rotation=0)
        axes3[idx_grafica].grid(True, alpha=0.3, axis='y')
        
        # Agregar etiquetas
        for i, val in enumerate(desercion_desplazados['Tasa_Desercion_%']):
            axes3[idx_grafica].text(i, val, f'{val:.1f}%', ha='center', va='bottom', fontweight='bold')
        
        print("\n--- Tasa de Deserción por DESPLAZADO_VICTIMA_CONFLICTO ---")
        print(desercion_desplazados)
        idx_grafica += 1
    
    plt.tight_layout()
    plt.show()
    
    # ========================================================================
    # 6. RESUMEN DE HALLAZGOS
    # ========================================================================
    print("\n" + "="*80)
    print("RESUMEN DE HALLAZGOS CLAVE")
    print("="*80)
    
    print(f"""
    CORRELACIONES NUMÉRICAS:
    • Se encontraron {len(correlaciones_fuertes) if correlaciones_fuertes else 0} correlaciones fuertes (|r| > 0.3)
    
    VARIABLES CATEGÓRICAS SIGNIFICATIVAS:
    • Variables con impacto significativo en NOTA (p < 0.05): {len([r for r in anova_results if r['p-value'] < 0.05])}
    
    FACTORES DE RIESGO DE DESERCIÓN:
    • Estrato con mayor deserción: {desercion_estrato['Tasa_Desercion_%'].idxmax() if 'ESTRATO' in df.columns else 'N/A'}
    • First Generation con mayor deserción: {desercion_fg['Tasa_Desercion_%'].idxmax() if 'FIRST_GENERATION' in df.columns else 'N/A'}
    """)

# %%
analizar_correlaciones(notas)
# Out:
# ================================================================================
# ANÁLISIS DE CORRELACIONES Y RELACIONES
# ================================================================================
#
# --------------------------------------------------------------------------------
# 1. CORRELACIÓN ENTRE VARIABLES NUMÉRICAS
# --------------------------------------------------------------------------------
#
# --- Matriz de Correlación ---
#                   NOTA_PROMEDIO  CREDITOS_TOTALES  NUM_MATERIAS  DESERTOR  \
# NOTA_PROMEDIO             1.000             0.320         0.333    -0.516
# CREDITOS_TOTALES          0.320             1.000         0.962    -0.605
# NUM_MATERIAS              0.333             0.962         1.000    -0.602
# DESERTOR                 -0.516            -0.605        -0.602     1.000
# GRADUADO                  0.370             0.727         0.681    -0.724
# ACTIVO                    0.181            -0.201        -0.139    -0.294
#
#                   GRADUADO  ACTIVO
# NOTA_PROMEDIO        0.370   0.181
# CREDITOS_TOTALES     0.727  -0.201
# NUM_MATERIAS         0.681  -0.139
# DESERTOR            -0.724  -0.294
# GRADUADO             1.000  -0.433
# ACTIVO              -0.433   1.000
# --- Correlaciones más fuertes (|r| > 0.3) ---
#       Variable 1       Variable 2  Correlación
# CREDITOS_TOTALES     NUM_MATERIAS     0.961941
# CREDITOS_TOTALES         GRADUADO     0.727275
#         DESERTOR         GRADUADO    -0.723598
#     NUM_MATERIAS         GRADUADO     0.680913
# CREDITOS_TOTALES         DESERTOR    -0.604589
#     NUM_MATERIAS         DESERTOR    -0.601522
#    NOTA_PROMEDIO         DESERTOR    -0.515821
#         GRADUADO           ACTIVO    -0.432981
#    NOTA_PROMEDIO         GRADUADO     0.370236
#    NOTA_PROMEDIO     NUM_MATERIAS     0.332835
#    NOTA_PROMEDIO CREDITOS_TOTALES     0.320098
#
# --------------------------------------------------------------------------------
# 2. RELACIÓN ENTRE VARIABLES CATEGÓRICAS Y NOTA
# --------------------------------------------------------------------------------
#
# --- Análisis de Varianza (ANOVA) ---
# Mide si las diferencias de NOTA entre categorías son estadísticamente significativas
# F-statistic alto = Mayor diferencia entre grupos
#
#                     Variable  F-statistic       p-value Significativo
#                      ESCUELA  7422.400783  0.000000e+00            Sí
#             FIRST_GENERATION   907.348432 2.723803e-199            Sí
#                      ESTRATO   224.326763 3.183871e-240            Sí
# DESPLAZADO_VICTIMA_CONFLICTO   204.945851  1.748633e-46            Sí
#
# --------------------------------------------------------------------------------
# 3. VISUALIZACIÓN DE RELACIONES CATEGÓRICAS
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# 4. RELACIÓN ENTRE VARIABLES DEMOGRÁFICAS Y ESTADO DEL ESTUDIANTE
# --------------------------------------------------------------------------------
#
# --- Tasa de Deserción por ESTRATO ---
#          Desertores  Total_Estudiantes  Tasa_Desercion_%
# ESTRATO
# 1               831               2005             41.45
# 4              3752              10934             34.31
# 3              3828              11268             33.97
# 2              1476               4540             32.51
# 6              4661              14678             31.76
# 5              4707              14981             31.42
#
# --- Tasa de Deserción por FIRST_GENERATION ---
#                   Desertores  Total_Estudiantes  Tasa_Desercion_%
# FIRST_GENERATION
# False                  16075              47851             33.59
# True                    3180              10555             30.13
#
# --- Tasa de Deserción por DISCAPACIDAD ---
#                   Desertores  Total_Estudiantes  Tasa_Desercion_%
# DISCAPACIDAD
# Visión                   216                591             36.55
# Auditiva                  24                 67             35.82
# Aprendizaje                7                 21             33.33
# Sin discapacidad       18991              57656             32.94
# Movilidad                 12                 40             30.00
# Médica                     4                 19             21.05
# Otra                       1                 12              8.33
#
# --------------------------------------------------------------------------------
# 5. VISUALIZACIÓN DE TASAS DE DESERCIÓN
# --------------------------------------------------------------------------------
#
# --- Tasa de Deserción por DESPLAZADO_VICTIMA_CONFLICTO ---
#                               Desertores  Total_Estudiantes  Tasa_Desercion_%
# DESPLAZADO_VICTIMA_CONFLICTO
# False                              19192              58074             33.05
# True                                  63                332             18.98
# ================================================================================
# RESUMEN DE HALLAZGOS CLAVE
# ================================================================================
#
#     CORRELACIONES NUMÉRICAS:
#     • Se encontraron 11 correlaciones fuertes (|r| > 0.3)
#
#     VARIABLES CATEGÓRICAS SIGNIFICATIVAS:
#     • Variables con impacto significativo en NOTA (p < 0.05): 4
#
#     FACTORES DE RIESGO DE DESERCIÓN:
#     • Estrato con mayor deserción: 1
#     • First Generation con mayor deserción: False

# %% [markdown]
# # 11. RESUMEN EJECUTIVO

# %%
def generar_resumen_ejecutivo(df):
    """
    Genera un resumen ejecutivo con los hallazgos principales
    """
    print("\n" + "="*80)
    print("RESUMEN EJECUTIVO")
    print("="*80)
    
    estudiantes_unicos = df['EMPLID_ANÓNIMO'].nunique()
    
    print(f"""
    INDICADORES CLAVE:
    ------------------
    • Total de registros: {len(df):,}
    • Estudiantes únicos: {estudiantes_unicos:,}
    • Materias únicas: {df['ID_MATERIA'].nunique():,}
    • Programas académicos: {df['NOMBRE_PROGRAMA'].nunique()}
    • Escuelas: {df['ESCUELA'].nunique()}
    • Rango temporal: {df['SEMESTRE'].min()} - {df['SEMESTRE'].max()}
    
    RENDIMIENTO ACADÉMICO:
    ----------------------
    • Nota promedio general: {df['NOTA'].mean():.2f}
    • Mediana de notas: {df['NOTA'].median():.2f}
    • Desviación estándar: {df['NOTA'].std():.2f}
    • Tasa de aprobación: {((df['NOTA'] >= 3.0).sum() / len(df) * 100):.2f}%
    
    ESCUELA CON MEJOR RENDIMIENTO:
    ------------------------------
    {df.groupby('ESCUELA')['NOTA'].mean().idxmax()}: {df.groupby('ESCUELA')['NOTA'].mean().max():.2f}
    
    ESCUELA CON MAYOR MATRÍCULA:
    ----------------------------
    {df['ESCUELA'].value_counts().idxmax()}: {df['ESCUELA'].value_counts().max():,} registros
    """)
    
    if 'DESERTOR' in df.columns:
        tasa_desercion = df.groupby('EMPLID_ANÓNIMO')['DESERTOR'].first().mean() * 100
        print(f"""
    INDICADORES DE PERMANENCIA ESTUDIANTIL:
    -------------------------
    • Tasa de deserción: {tasa_desercion:.2f}%
    • Tasa de graduación: {df.groupby('EMPLID_ANÓNIMO')['GRADUADO'].first().mean() * 100:.2f}%
    • Estudiantes activos: {df.groupby('EMPLID_ANÓNIMO')['ACTIVO'].first().mean() * 100:.2f}%
        """)

# %%
generar_resumen_ejecutivo(notas)
# Out:
# ================================================================================
# RESUMEN EJECUTIVO
# ================================================================================
#
#     INDICADORES CLAVE:
#     ------------------
#     • Total de registros: 2,194,612
#     • Estudiantes únicos: 58,406
#     • Materias únicas: 7,679
#     • Programas académicos: 32
#     • Escuelas: 5
#     • Rango temporal: 2000-1 - 2025-2
#
#     RENDIMIENTO ACADÉMICO:
#     ----------------------
#     • Nota promedio general: 3.86
#     • Mediana de notas: 4.00
#     • Desviación estándar: 0.82
#     • Tasa de aprobación: 92.57%
#
#     ESCUELA CON MEJOR RENDIMIENTO:
#     ------------------------------
#     Escuela de Artes y Humanidades: 4.15
#
#     ESCUELA CON MAYOR MATRÍCULA:
#     ----------------------------
#     Escuela de Administración: 933,521 registros
#
#
#     INDICADORES DE PERMANENCIA ESTUDIANTIL:
#     -------------------------
#     • Tasa de deserción: 32.97%
#     • Tasa de graduación: 51.56%
#     • Estudiantes activos: 14.97%

# %% [markdown]
# # 12. FILTRADO DEL DATASET

# %%
notas.ESCUELA.unique()
# Out:
# array(['Escuela de Artes y Humanidades', 'Escuela de Administración',
#        'E.Finanzas, Economía, Gobierno', 'Escuela de Derecho',
#        'E Ciencias Aplic e Ingeniería'], dtype=object)

# %% [markdown]
# ### 12.1 OPCION 1: FILTRAR ESCUELA + FILTRAR MATERIAS

# %%
notas_filtrado=notas[notas['ESCUELA']=='E Ciencias Aplic e Ingeniería']

# %%
notas_filtrado.shape
# Out:
# (811385, 24)

# %%
notas_filtrado = notas_filtrado[notas_filtrado['ID_MATERIA'].isin(['106953', '108874', '107052', '106946', '108779', '119530', '106680', '107366', '132288', 
        '106679', '107062', '107222', '107662', '106954', '111069', '107058', '114194', 
        '118623', '132289', '114186', '118617', '107395', '118598', '118597', '107393','107274',
        '107057','108821','108879','106936','108822','107391','132342','107392','107462','107853','107390','108820','106973',
        '107056','108813','108878','106846','106975','119567','108818','132296','107442','119582','108913','107387',
        '109034','107230','107287','107819','107669','107816','107388','107815','107820','108872','109089','106974','107389','108776',
        '107272','107053','108790','108875','106934','108796','132299','107373','107229','107668','107371','107372','110387',
        '126186','108827','108882','107066','107030','108829','106874','126145','107416'])]

# %%
notas_filtrado.shape
# Out:
# (74125, 24)

# %%
def crear_nombre_corto_materia(df):
    """
    Crea nombres cortos para las materias para mejor visualización
    Versión afinada - captura todas las variaciones
    """
    def obtener_nombre_corto(nombre):
        nombre_lower = nombre.lower()
        
        # Cálculo 1 (Cálculo Diferencial)
        # Captura: CÁLCULO I, CÁLCULO 1, CÁLCULO DIFERENCIAL, CÁLC. DIFER., METOD (CÁLCULO DIFERENCIAL)
        if any(x in nombre_lower for x in ['cálculo i', 'calculo i', 'cálculo 1', 'calculo 1', 
                                             'cálc. difer', 'calculo difer', 'cálculo diferencial', 
                                             'calculo diferencial', 'metod (cálculo diferencial)']):
            return 'Cálculo 1'
        
        # Cálculo 2 (Cálculo Integral)
        # Captura: CÁLCULO II, CÁLCULO 2, CÁLCULO INTEGRAL, CÁLC. INT.
        if any(x in nombre_lower for x in ['cálculo ii', 'calculo ii', 'cálculo 2', 'calculo 2',
                                             'cálc. int', 'calculo int', 'cálculo integral', 
                                             'calculo integral']):
            return 'Cálculo 2'
        
        # Estadística
        # Captura cualquier variación de estadística
        if 'estadística' in nombre_lower or 'estadistica' in nombre_lower:
            return 'Estadística'
        
        # Álgebra Lineal
        # Captura cualquier variación de álgebra lineal
        if 'álgebra lineal' in nombre_lower or 'algebra lineal' in nombre_lower:
            return 'Álgebra Lineal'
        
        # Ecuaciones Diferenciales
        # Captura todas las variaciones
        if any(x in nombre_lower for x in ['ecuaciones dif', 'ecuac. dif', 'ec. dif', 
                                             'ecuaciones diferencial']):
            return 'Ecuaciones'
        
        # Física
        # Captura cualquier variación de física
        if 'física' in nombre_lower or 'fisica' in nombre_lower:
            return 'Física 1'
        
        # Si no coincide con ninguno, retornar el nombre original
        return nombre
    
    df['MATERIA_CORTA'] = df['NOMBRE_MATERIA'].apply(obtener_nombre_corto)
    return df

# %%
crear_nombre_corto_materia(notas_filtrado)
# Out:
#         EMPLID_ANÓNIMO NIVEL_ACADEMICO SEMESTRE ID_MATERIA NRO_MATERIA  \
# 49               41453            PREG   2022-1     111069      DF0236
# 61               41271            PREG   2024-1     111069      DF0236
# 62               57507            PREG   2024-1     111069      DF0236
# 63               70220            PREG   2024-1     111069      DF0236
# 65               52809            PREG   2024-1     111069      DF0236
# ...                ...             ...      ...        ...         ...
# 2118434           3296            PREG   2020-1     108790      CM0084
# 2118437           3296            PREG   2019-2     108874      CM0230
# 2118618          28293            PREG   2005-2     106936      CB0114
# 2118619          28293            PREG   2005-2     106874      CB0051
# 2118622          28293            PREG   2005-1     106846      CB0023
#
#                    NOMBRE_MATERIA COD_PROGRAMA  \
# 49                       FÍSICA I           13
# 61                       FÍSICA I           10
# 62                       FÍSICA I           10
# 63                       FÍSICA I           10
# 65                       FÍSICA I           12
# ...                           ...          ...
# 2118434                CÁLCULO II          230
# 2118437                 CÁLCULO I          230
# 2118618  ECUACIONES DIFERENCIALES           82
# 2118619       ESTADÍSTICA GENERAL           82
# 2118622            ÁLGEBRA LINEAL           82
#
#                         NOMBRE_PROGRAMA                        ESCUELA  \
# 49                     Ingeniería Civil  E Ciencias Aplic e Ingeniería
# 61               Ingeniería de Sistemas  E Ciencias Aplic e Ingeniería
# 62               Ingeniería de Sistemas  E Ciencias Aplic e Ingeniería
# 63               Ingeniería de Sistemas  E Ciencias Aplic e Ingeniería
# 65             Ingeniería de Producción  E Ciencias Aplic e Ingeniería
# ...                                 ...                            ...
# 2118434           Ingeniería Agronómica  E Ciencias Aplic e Ingeniería
# 2118437           Ingeniería Agronómica  E Ciencias Aplic e Ingeniería
# 2118618  Ingeniería Civil - Llanogrande  E Ciencias Aplic e Ingeniería
# 2118619  Ingeniería Civil - Llanogrande  E Ciencias Aplic e Ingeniería
# 2118622  Ingeniería Civil - Llanogrande  E Ciencias Aplic e Ingeniería
#
#         NIVEL_ACADÉMICO_CURSO  ... DESPLAZADO_VICTIMA_CONFLICTO  COHORTE  \
# 49                       PREG  ...                        False   2022-1
# 61                       PREG  ...                        False   2023-1
# 62                       PREG  ...                        False   2023-2
# 63                       PREG  ...                        False   2021-1
# 65                       PREG  ...                        False   2023-2
# ...                       ...  ...                          ...      ...
# 2118434                  PREG  ...                        False   2019-2
# 2118437                  PREG  ...                        False   2019-2
# 2118618                  PREG  ...                        False   2004-1
# 2118619                  PREG  ...                        False   2004-1
# 2118622                  PREG  ...                        False   2004-1
#
#          DESERTOR GRADUADO  ACTIVO  ESTRATO       CATEGORIA_NOTA  APROBADO  \
# 49           True    False   False        4       Bajo (2.5-3.0)         0
# 61          False    False    True        5       Bajo (2.5-3.0)         1
# 62           True    False   False        4     Muy Bajo (0-2.5)         0
# 63           True    False   False        5     Muy Bajo (0-2.5)         0
# 65          False    False    True        6      Medio (3.0-3.5)         1
# ...           ...      ...     ...      ...                  ...       ...
# 2118434     False     True   False        5      Bueno (3.5-4.0)         1
# 2118437     False     True   False        5  Excelente (4.0-5.0)         1
# 2118618     False     True   False        4       Bajo (2.5-3.0)         1
# 2118619     False     True   False        4      Medio (3.0-3.5)         1
# 2118622     False     True   False        4      Medio (3.0-3.5)         1
#
#           AÑO   MATERIA_CORTA
# 49       2022        Física 1
# 61       2024        Física 1
# 62       2024        Física 1
# 63       2024        Física 1
# 65       2024        Física 1
# ...       ...             ...
# 2118434  2020       Cálculo 1
# 2118437  2019       Cálculo 1
# 2118618  2005      Ecuaciones
# 2118619  2005     Estadística
# 2118622  2005  Álgebra Lineal
#
# [74125 rows x 25 columns]

# %%
notas_filtrado.MATERIA_CORTA.unique()
# Out:
# array(['Física 1', 'Álgebra Lineal', 'Cálculo 2', 'Cálculo 1',
#        'Estadística', 'Ecuaciones'], dtype=object)

# %%
notas_filtrado['TIENE_DISCAPACIDAD'] = np.where(
    notas_filtrado['DISCAPACIDAD'] == 'Sin discapacidad', 0, 1
)

# %% [markdown]
# ### 12.2. AGRUPAR Y PIVOTEAR COLUMNAS DE MATERIAS ELEGIDAS

# %%
notas_filtrado.columns
# Out:
# Index(['EMPLID_ANÓNIMO', 'NIVEL_ACADEMICO', 'SEMESTRE', 'ID_MATERIA',
#        'NRO_MATERIA', 'NOMBRE_MATERIA', 'COD_PROGRAMA', 'NOMBRE_PROGRAMA',
#        'ESCUELA', 'NIVEL_ACADÉMICO_CURSO', 'SISTEMA_CALIFICACION', 'NOTA',
#        'CRÉDITOS', 'DISCAPACIDAD', 'FIRST_GENERATION',
#        'DESPLAZADO_VICTIMA_CONFLICTO', 'COHORTE', 'DESERTOR', 'GRADUADO',
#        'ACTIVO', 'ESTRATO', 'CATEGORIA_NOTA', 'APROBADO', 'AÑO',
#        'MATERIA_CORTA', 'TIENE_DISCAPACIDAD'],
#       dtype='object')

# %%
notas_filtrado_agrupado1=notas_filtrado.groupby(['EMPLID_ANÓNIMO', 'COD_PROGRAMA', 'NOMBRE_PROGRAMA','DESERTOR','GRADUADO','ACTIVO','FIRST_GENERATION', 'DESPLAZADO_VICTIMA_CONFLICTO', 'ESTRATO', 'MATERIA_CORTA', 'TIENE_DISCAPACIDAD','COHORTE'], as_index=False, sort=False).agg({'NOTA':'mean'})

# %%
notas_filtrado_agrupado1.shape
# Out:
# (52236, 13)

# %%
notas_filtrado_agrupado1[notas_filtrado_agrupado1['EMPLID_ANÓNIMO']=='1002']
# Out:
#       EMPLID_ANÓNIMO COD_PROGRAMA           NOMBRE_PROGRAMA  DESERTOR  \
# 719             1002           12  Ingeniería de Producción     False
# 877             1002           12  Ingeniería de Producción     False
# 39488           1002           12  Ingeniería de Producción     False
#
#        GRADUADO  ACTIVO  FIRST_GENERATION  DESPLAZADO_VICTIMA_CONFLICTO  \
# 719        True   False             False                         False
# 877        True   False             False                         False
# 39488      True   False             False                         False
#
#        ESTRATO   MATERIA_CORTA  TIENE_DISCAPACIDAD COHORTE  NOTA
# 719          5       Cálculo 1                   0  2002-1   3.2
# 877          5  Álgebra Lineal                   0  2002-1   3.9
# 39488        5      Ecuaciones                   0  2002-1   3.5

# %%
notas_filtrado_pivoteado = notas_filtrado_agrupado1.pivot_table(
    index=['EMPLID_ANÓNIMO', 'COD_PROGRAMA', 'NOMBRE_PROGRAMA','DESERTOR','GRADUADO','ACTIVO','FIRST_GENERATION', 'DESPLAZADO_VICTIMA_CONFLICTO', 'ESTRATO', 'TIENE_DISCAPACIDAD','COHORTE'],
    columns='MATERIA_CORTA',
    values='NOTA',
    aggfunc='mean'
)

# %%
notas_filtrado_pivoteado.reset_index(inplace=True)

# %%
notas_filtrado_pivoteado.shape
# Out:
# (18129, 17)

# %%
notas_filtrado_pivoteado[notas_filtrado_pivoteado['EMPLID_ANÓNIMO']=='10072']
# Out:
# MATERIA_CORTA EMPLID_ANÓNIMO COD_PROGRAMA         NOMBRE_PROGRAMA  DESERTOR  \
# 84                     10072           10  Ingeniería de Sistemas      True
# 85                     10072           13        Ingeniería Civil     False
#
# MATERIA_CORTA  GRADUADO  ACTIVO  FIRST_GENERATION  \
# 84                False   False             False
# 85                False    True             False
#
# MATERIA_CORTA  DESPLAZADO_VICTIMA_CONFLICTO  ESTRATO  TIENE_DISCAPACIDAD  \
# 84                                    False        4                   0
# 85                                    False        4                   0
#
# MATERIA_CORTA COHORTE  Cálculo 1  Cálculo 2  Ecuaciones  Estadística  \
# 84             2019-1        3.0        NaN         NaN          NaN
# 85             2019-2        3.2        NaN         4.7          3.1
#
# MATERIA_CORTA  Física 1  Álgebra Lineal
# 84                  NaN             NaN
# 85                 2.75             3.4

# %%
# Lista de columnas de materias
materias = ['Cálculo 1', 'Cálculo 2', 'Ecuaciones',
             'Estadística', 'Física 1', 'Álgebra Lineal']

# Contar cuántos estudiantes tienen todas las notas
completos = notas_filtrado_pivoteado[materias].notna().all(axis=1).sum()

print(f"Estudiantes con notas en todas las materias: {completos}")
# Out:
# Estudiantes con notas en todas las materias: 0

# %%
# FALTANTES
materias = ['Cálculo 1', 'Cálculo 2', 'Ecuaciones',
             'Estadística', 'Física 1', 'Álgebra Lineal']

faltantes_por_materia = notas_filtrado_pivoteado[materias].isna().sum()

print(faltantes_por_materia)
# Out:
# MATERIA_CORTA
# Cálculo 1          1605
# Cálculo 2         17889
# Ecuaciones         8767
# Estadística       10628
# Física 1           9919
# Álgebra Lineal     7730
# dtype: int64

# %%
# CON NOTAS

materias = ['Cálculo 1', 'Cálculo 2', 'Ecuaciones',
             'Estadística', 'Física 1', 'Álgebra Lineal']

con_nota_por_materia = notas_filtrado_pivoteado[materias].notna().sum()

print(con_nota_por_materia)
# Out:
# MATERIA_CORTA
# Cálculo 1         16524
# Cálculo 2           240
# Ecuaciones         9362
# Estadística        7501
# Física 1           8210
# Álgebra Lineal    10399
# dtype: int64

# %%
notas_filtrado_pivoteado['Cálculo 1']=notas_filtrado_pivoteado['Cálculo 1'].fillna(0)
notas_filtrado_pivoteado['Cálculo 2']=notas_filtrado_pivoteado['Cálculo 2'].fillna(0)
notas_filtrado_pivoteado['Ecuaciones']=notas_filtrado_pivoteado['Ecuaciones'].fillna(0)
notas_filtrado_pivoteado['Estadística']=notas_filtrado_pivoteado['Estadística'].fillna(0)
notas_filtrado_pivoteado['Física 1']=notas_filtrado_pivoteado['Física 1'].fillna(0)
notas_filtrado_pivoteado['Álgebra Lineal']=notas_filtrado_pivoteado['Álgebra Lineal'].fillna(0)

# %%
materias = ['Cálculo 1', 'Cálculo 2', 'Ecuaciones',
             'Estadística', 'Física 1', 'Álgebra Lineal']

notas_filtrado_pivoteado['PROMEDIO_MATERIAS'] = notas_filtrado_pivoteado[materias].mean(axis=1, skipna=True)

# %%
materias = ['Cálculo 1', 'Cálculo 2', 'Ecuaciones', 'Estadística', 'Física 1', 'Álgebra Lineal']

# Cuenta cuántas notas no son NaN por fila solo en esas columnas
notas_filtrado_pivoteado['NUM_MATERIAS_CON_NOTA'] = notas_filtrado_pivoteado[materias].count(axis=1)

# %%
notas_filtrado_pivoteado.head()
# Out:
# MATERIA_CORTA EMPLID_ANÓNIMO COD_PROGRAMA           NOMBRE_PROGRAMA  DESERTOR  \
# 0                       1000           12  Ingeniería de Producción     False
# 1                     100037           10    Ingeniería de Sistemas     False
# 2                     100040           10    Ingeniería de Sistemas     False
# 3                     100044            4    Ingeniería de Procesos     False
# 4                     100088           10    Ingeniería de Sistemas     False
#
# MATERIA_CORTA  GRADUADO  ACTIVO  FIRST_GENERATION  \
# 0                  True   False             False
# 1                 False    True             False
# 2                 False    True             False
# 3                  True   False             False
# 4                 False    True             False
#
# MATERIA_CORTA  DESPLAZADO_VICTIMA_CONFLICTO  ESTRATO  TIENE_DISCAPACIDAD  \
# 0                                     False        1                   0
# 1                                     False        6                   0
# 2                                     False        5                   0
# 3                                     False        5                   0
# 4                                     False        4                   0
#
# MATERIA_CORTA COHORTE  Cálculo 1  Cálculo 2  Ecuaciones  Estadística  \
# 0              2002-2       3.25        0.0         0.0          0.0
# 1              2025-1       4.50        0.0         0.0          0.0
# 2              2025-1       3.40        0.0         0.0          0.0
# 3              2005-1       3.10        0.0         3.0          0.0
# 4              2025-1       3.00        0.0         0.0          0.0
#
# MATERIA_CORTA  Física 1  Álgebra Lineal  PROMEDIO_MATERIAS  \
# 0                   0.0             3.5           1.125000
# 1                   0.0             0.0           0.750000
# 2                   0.0             0.0           0.566667
# 3                   0.0             3.5           1.600000
# 4                   0.0             0.0           0.500000
#
# MATERIA_CORTA  NUM_MATERIAS_CON_NOTA
# 0                                  6
# 1                                  6
# 2                                  6
# 3                                  6
# 4                                  6

# %% [markdown]
# ### 12.3. Normalizar variables

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# 🔹 Opción A: Min-Max Scaling (0 a 1)

# Ideal si quieres que todos los valores estén entre 0 y 1.


scaler = MinMaxScaler()

notas_filtrado_pivoteado['PROMEDIO_NORMALIZADO'] = scaler.fit_transform(
    notas_filtrado_pivoteado[['PROMEDIO_MATERIAS']]
)

# %%
# 🔹 Opción A: Min-Max Scaling (0 a 1)

# Ideal si quieres que todos los valores estén entre 0 y 1.


scaler = MinMaxScaler()

notas_filtrado_pivoteado['CALCULO1_NORMALIZADO'] = scaler.fit_transform(
    notas_filtrado_pivoteado[['Cálculo 1']]
)

# %%
# 🔹 Opción A: Min-Max Scaling (0 a 1)

# Ideal si quieres que todos los valores estén entre 0 y 1.


scaler = MinMaxScaler()

notas_filtrado_pivoteado['CALCULO2_NORMALIZADO'] = scaler.fit_transform(
    notas_filtrado_pivoteado[['Cálculo 2']]
)

# %%
# 🔹 Opción A: Min-Max Scaling (0 a 1)

# Ideal si quieres que todos los valores estén entre 0 y 1.


scaler = MinMaxScaler()

notas_filtrado_pivoteado['ECUACIONES_NORMALIZADO'] = scaler.fit_transform(
    notas_filtrado_pivoteado[['Ecuaciones']]
)

# %%
# 🔹 Opción A: Min-Max Scaling (0 a 1)

# Ideal si quieres que todos los valores estén entre 0 y 1.


scaler = MinMaxScaler()

notas_filtrado_pivoteado['ESTADISTICA_NORMALIZADO'] = scaler.fit_transform(
    notas_filtrado_pivoteado[['Estadística']]
)

# %%
# 🔹 Opción A: Min-Max Scaling (0 a 1)

# Ideal si quieres que todos los valores estén entre 0 y 1.


scaler = MinMaxScaler()

notas_filtrado_pivoteado['FÍSICA1_NORMALIZADO'] = scaler.fit_transform(
    notas_filtrado_pivoteado[['Física 1']]
)

# %%
# 🔹 Opción A: Min-Max Scaling (0 a 1)

# Ideal si quieres que todos los valores estén entre 0 y 1.


scaler = MinMaxScaler()

notas_filtrado_pivoteado['ALGEBRA_LINEAL_NORMALIZADO'] = scaler.fit_transform(
    notas_filtrado_pivoteado[['Álgebra Lineal']]
)

# %%
# 🔹 Opción A: Min-Max Scaling (0 a 1)

# Ideal si quieres que todos los valores estén entre 0 y 1.


scaler = MinMaxScaler()

notas_filtrado_pivoteado['ESTRATO_NORMALIZADO'] = scaler.fit_transform(
    notas_filtrado_pivoteado[['ESTRATO']]
)

# %%
# 🔹 Opción A: Min-Max Scaling (0 a 1)

# Ideal si quieres que todos los valores estén entre 0 y 1.


scaler = MinMaxScaler()

notas_filtrado_pivoteado['NUM_MATERIAS_NORMALIZADO'] = scaler.fit_transform(
    notas_filtrado_pivoteado[['NUM_MATERIAS_CON_NOTA']]
)

# %%
cohortes_filtrar = ['2010-1','2010-2','2011-1','2011-2','2012-1','2012-2','2013-1','2013-2','2014-1','2014-2',
                    '2015-1','2015-2','2016-1','2016-2','2017-1','2017-2','2018-1','2018-2','2019-1','2019-2',
                   '2020-1','2020-2','2021-1','2021-2','2022-1','2022-2','2023-1','2023-2','2024-1','2024-2']
base_ML = notas_filtrado_pivoteado[notas_filtrado_pivoteado['COHORTE'].isin(cohortes_filtrar)]

# %% [markdown]
# ### 12.4. Matriz de correlacion con variables normalizadas

# %%
cohortes_filtrar = ['2010-1','2010-2','2011-1','2011-2','2012-1','2012-2','2013-1','2013-2','2014-1','2014-2',
                    '2015-1','2015-2','2016-1','2016-2','2017-1','2017-2','2018-1','2018-2','2019-1','2019-2']
notas_filtrado_pivoteado = notas_filtrado_pivoteado[notas_filtrado_pivoteado['COHORTE'].isin(cohortes_filtrar)]

# %%
notas_filtrado_pivoteado.columns
# Out:
# Index(['EMPLID_ANÓNIMO', 'COD_PROGRAMA', 'NOMBRE_PROGRAMA', 'DESERTOR',
#        'GRADUADO', 'ACTIVO', 'FIRST_GENERATION',
#        'DESPLAZADO_VICTIMA_CONFLICTO', 'ESTRATO', 'TIENE_DISCAPACIDAD',
#        'COHORTE', 'Cálculo 1', 'Cálculo 2', 'Ecuaciones', 'Estadística',
#        'Física 1', 'Álgebra Lineal', 'PROMEDIO_MATERIAS',
#        'NUM_MATERIAS_CON_NOTA', 'PROMEDIO_NORMALIZADO', 'CALCULO1_NORMALIZADO',
#        'CALCULO2_NORMALIZADO', 'ECUACIONES_NORMALIZADO',
#        'ESTADISTICA_NORMALIZADO', 'FÍSICA1_NORMALIZADO',
#        'ALGEBRA_LINEAL_NORMALIZADO', 'ESTRATO_NORMALIZADO',
#        'NUM_MATERIAS_NORMALIZADO'],
#       dtype='object', name='MATERIA_CORTA')

# %%
# 1️⃣ Seleccionar las columnas necesarias
cols_correlacion = [ 'ESTRATO_NORMALIZADO', 'FIRST_GENERATION',  'DESPLAZADO_VICTIMA_CONFLICTO', 'TIENE_DISCAPACIDAD',
                    'DESERTOR',
                    'CALCULO1_NORMALIZADO',
                    'ECUACIONES_NORMALIZADO',
                    'ESTADISTICA_NORMALIZADO', 
                    'FÍSICA1_NORMALIZADO',
                    'ALGEBRA_LINEAL_NORMALIZADO']

# 3️⃣ Filtrar el dataframe
df_corr = notas_filtrado_pivoteado[cols_correlacion]

# 4️⃣ Calcular la matriz de correlación (solo numéricas)
matriz_corr = df_corr.corr(numeric_only=True)

# 5️⃣ Mostrar la matriz de correlación numérica
print(matriz_corr.round(2))

# 6️⃣ (Opcional) Visualizar con un heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(matriz_corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Matriz de correlación de variables normalizadas")
plt.show()
# Out:
# MATERIA_CORTA                 ESTRATO_NORMALIZADO  FIRST_GENERATION  \
# MATERIA_CORTA
# ESTRATO_NORMALIZADO                          1.00             -0.36
# FIRST_GENERATION                            -0.36              1.00
# DESPLAZADO_VICTIMA_CONFLICTO                -0.02              0.01
# TIENE_DISCAPACIDAD                          -0.05              0.03
# DESERTOR                                    -0.08              0.04
# CALCULO1_NORMALIZADO                         0.09             -0.05
# ECUACIONES_NORMALIZADO                       0.14             -0.08
# ESTADISTICA_NORMALIZADO                      0.03             -0.04
# FÍSICA1_NORMALIZADO                         -0.04              0.04
# ALGEBRA_LINEAL_NORMALIZADO                  -0.00              0.02
#
# MATERIA_CORTA                 DESPLAZADO_VICTIMA_CONFLICTO  \
# MATERIA_CORTA
# ESTRATO_NORMALIZADO                                  -0.02
# FIRST_GENERATION                                      0.01
# DESPLAZADO_VICTIMA_CONFLICTO                          1.00
# TIENE_DISCAPACIDAD                                   -0.01
# DESERTOR                                             -0.03
# CALCULO1_NORMALIZADO                                  0.01
# ECUACIONES_NORMALIZADO                               -0.00
# ESTADISTICA_NORMALIZADO                              -0.00
# FÍSICA1_NORMALIZADO                                   0.02
# ALGEBRA_LINEAL_NORMALIZADO                            0.03
#
# MATERIA_CORTA                 TIENE_DISCAPACIDAD  DESERTOR  \
# MATERIA_CORTA
# ESTRATO_NORMALIZADO                        -0.05     -0.08
# FIRST_GENERATION                            0.03      0.04
# DESPLAZADO_VICTIMA_CONFLICTO               -0.01     -0.03
# TIENE_DISCAPACIDAD                          1.00      0.03
# DESERTOR                                    0.03      1.00
# CALCULO1_NORMALIZADO                       -0.04     -0.38
# ECUACIONES_NORMALIZADO                     -0.04     -0.53
# ESTADISTICA_NORMALIZADO                    -0.02     -0.53
# FÍSICA1_NORMALIZADO                        -0.02     -0.27
# ALGEBRA_LINEAL_NORMALIZADO                  0.00     -0.37
#
# MATERIA_CORTA                 CALCULO1_NORMALIZADO  ECUACIONES_NORMALIZADO  \
# MATERIA_CORTA
# ESTRATO_NORMALIZADO                           0.09                    0.14
# FIRST_GENERATION                             -0.05                   -0.08
# DESPLAZADO_VICTIMA_CONFLICTO                  0.01                   -0.00
# TIENE_DISCAPACIDAD                           -0.04                   -0.04
# DESERTOR                                     -0.38                   -0.53
# CALCULO1_NORMALIZADO                          1.00                    0.41
# ECUACIONES_NORMALIZADO                        0.41                    1.00
# ESTADISTICA_NORMALIZADO                       0.35                    0.31
# FÍSICA1_NORMALIZADO                           0.49                    0.27
# ALGEBRA_LINEAL_NORMALIZADO                    0.38                    0.42
#
# MATERIA_CORTA                 ESTADISTICA_NORMALIZADO  FÍSICA1_NORMALIZADO  \
# MATERIA_CORTA
# ESTRATO_NORMALIZADO                              0.03                -0.04
# FIRST_GENERATION                                -0.04                 0.04
# DESPLAZADO_VICTIMA_CONFLICTO                    -0.00                 0.02
# TIENE_DISCAPACIDAD                              -0.02                -0.02
# DESERTOR                                        -0.53                -0.27
# CALCULO1_NORMALIZADO                             0.35                 0.49
# ECUACIONES_NORMALIZADO                           0.31                 0.27
# ESTADISTICA_NORMALIZADO                          1.00                 0.17
# FÍSICA1_NORMALIZADO                              0.17                 1.00
# ALGEBRA_LINEAL_NORMALIZADO                       0.16                 0.65
#
# MATERIA_CORTA                 ALGEBRA_LINEAL_NORMALIZADO
# MATERIA_CORTA
# ESTRATO_NORMALIZADO                                -0.00
# FIRST_GENERATION                                    0.02
# DESPLAZADO_VICTIMA_CONFLICTO                        0.03
# TIENE_DISCAPACIDAD                                  0.00
# DESERTOR                                           -0.37
# CALCULO1_NORMALIZADO                                0.38
# ECUACIONES_NORMALIZADO                              0.42
# ESTADISTICA_NORMALIZADO                             0.16
# FÍSICA1_NORMALIZADO                                 0.65
# ALGEBRA_LINEAL_NORMALIZADO                          1.00
